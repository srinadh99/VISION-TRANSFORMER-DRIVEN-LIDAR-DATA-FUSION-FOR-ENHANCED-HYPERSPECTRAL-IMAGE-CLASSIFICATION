# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import sys
import os
import math
import time 

from einops import rearrange
import torch.optim as optim
from operator import truediv
# import torchvision
# from torchvision import datasets, transforms
from scipy import io
import torch.utils.data
import scipy.io as sio
# import mat73
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary
import copy
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score
from sklearn.model_selection import train_test_split
import record

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(device)
datasetname = 'UHouston'
# Out:
# cuda:1

# %%
hsi_2013_data=sio.loadmat('./'+str(datasetname)+'/2013_IEEE_GRSS_DF_Contest_CASI.mat')['HSI_data']
print('hsi_2013_data shape:', hsi_2013_data.shape)

# Loader Lidar  data
# import mat73
lidar_2013_data = sio.loadmat('./'+str(datasetname)+'/2013_IEEE_GRSS_DF_Contest_LiDAR.mat')['LiDAR_data']

print('Lidar_2013_data shape:', lidar_2013_data.shape)

#Load ground truth labels
gt_2013_data=sio.loadmat('./'+str(datasetname)+'/GRSS2013.mat')['name']
print('gt_2013_data.shape:', gt_2013_data.shape)
# Out:
# hsi_2013_data shape: (349, 1905, 144)
# Lidar_2013_data shape: (349, 1905, 1)
# gt_2013_data.shape: (349, 1905)

# %%
class_info = [(1, "Healthy grass", 'training_sample', 198, 'test_sample', 1053,  'total', 1251),
    (2, "Stressed grass",'training_sample', 190, 'test_sample', 1064,  'total', 1254),
    (3, "Synthetic grass", 'training_sample', 192, 'test_sample', 505,  'total', 697),
    (4, "Trees", 'training_sample', 188, 'test_sample', 1058,  'total', 1244),
    (5, "Soil",'training_sample', 186, 'test_sample', 1056,  'total', 1242),
    (6, "Water", 'training_sample', 182, 'test_sample', 141,  'total', 325),
    (7, "Residential", 'training_sample', 196, 'test_sample', 1072,  'total', 1268),
    (8, "Commercial", 'training_sample', 191, 'test_sample', 1053,  'total', 1244),
    (9, "Road", 'training_sample', 193, 'test_sample', 1059,  'total', 1252),
    (10, "Highway", 'training_sample', 191, 'test_sample', 1036,  'total', 1227),
    (11, "Railway", 'training_sample', 181, 'test_sample', 1054,  'total', 1235),
    (12, "Parking lot 1", 'training_sample', 192, 'test_sample', 1041,  'total', 1233),
    (13, "Parking lot 2", 'training_sample', 184, 'test_sample',285,  'total', 469),
    (14, "Tennis court",'training_sample', 181, 'test_sample', 247,  'total', 428),
    (15, "Running track", 'training_sample', 187, 'test_sample', 473,  'total', 660)]

# Create a dictionary to store class number, class name, and class samples
class_dict = {class_number: {"class_name": class_name,
                             'training_sample': training_sample,
                             'test_sample': test_sample,
                             "total_samples": total}
              for class_number, class_name, _, training_sample, _, test_sample, _, total in class_info}

print(class_dict)
# Out:
# {1: {'class_name': 'Healthy grass', 'training_sample': 198, 'test_sample': 1053, 'total_samples': 1251}, 2: {'class_name': 'Stressed grass', 'training_sample': 190, 'test_sample': 1064, 'total_samples': 1254}, 3: {'class_name': 'Synthetic grass', 'training_sample': 192, 'test_sample': 505, 'total_samples': 697}, 4: {'class_name': 'Trees', 'training_sample': 188, 'test_sample': 1058, 'total_samples': 1244}, 5: {'class_name': 'Soil', 'training_sample': 186, 'test_sample': 1056, 'total_samples': 1242}, 6: {'class_name': 'Water', 'training_sample': 182, 'test_sample': 141, 'total_samples': 325}, 7: {'class_name': 'Residential', 'training_sample': 196, 'test_sample': 1072, 'total_samples': 1268}, 8: {'class_name': 'Commercial', 'training_sample': 191, 'test_sample': 1053, 'total_samples': 1244}, 9: {'class_name': 'Road', 'training_sample': 193, 'test_sample': 1059, 'total_samples': 1252}, 10: {'class_name': 'Highway', 'training_sample': 191, 'test_sample': 1036, 'total_samples': 1227}, 11: {'class_name': 'Railway', 'training_sample': 181, 'test_sample': 1054, 'total_samples': 1235}, 12: {'class_name': 'Parking lot 1', 'training_sample': 192, 'test_sample': 1041, 'total_samples': 1233}, 13: {'class_name': 'Parking lot 2', 'training_sample': 184, 'test_sample': 285, 'total_samples': 469}, 14: {'class_name': 'Tennis court', 'training_sample': 181, 'test_sample': 247, 'total_samples': 428}, 15: {'class_name': 'Running track', 'training_sample': 187, 'test_sample': 473, 'total_samples': 660}}

# %%
# Define patch size and stride
patch_size = 9
stride = 1

# Create an empty list to store patches and labels
hsi_samples = []
lidar_samples = []
labels = []

# Initialize a dictionary to store class count
class_count = {i: 0 for i in class_dict.keys()}

# Function to check if all classes have the required number of samples
def all_classes_completed(class_count, class_dict):
    return all(class_count[class_num] == class_dict[class_num]["total_samples"] for class_num in class_dict.keys())

while not all_classes_completed(class_count, class_dict):
    # Loop through the ground truth data
    for label in class_dict.keys():
        # Get the coordinates of the ground truth pixels
        #coords = np.argwhere((gt_2013_data == label) & (mask > 0))
        coords = np.argwhere(gt_2013_data == label)

        # Shuffle the coordinates to randomize the patch extraction
        np.random.shuffle(coords)

        for coord in coords:
            i, j = coord
            # Calculate the patch indices
            i_start, i_end = i - patch_size // 2, i + patch_size // 2 + 1
            j_start, j_end = j - patch_size // 2, j + patch_size // 2 + 1

            # Check if the indices are within the bounds of the HSI data
            if i_start >= 0 and i_end <= hsi_2013_data.shape[0] and j_start >= 0 and j_end <= hsi_2013_data.shape[1]:
                # Extract the patch
                hsi_patch = hsi_2013_data[i_start:i_end, j_start:j_end, :]

                # Extract the LiDAR patch
                lidar_patch = lidar_2013_data[i_start:i_end, j_start:j_end, :]

                # If the class count is less than the required samples
                if class_count[label] < class_dict[label]["total_samples"]:
                    # Append the patch and its label to the list
                    hsi_samples.append(hsi_patch)
                    lidar_samples.append(lidar_patch)
                    labels.append(label)
                    class_count[label] += 1

                    # If all classes have the required number of samples, exit the loop
                    if all_classes_completed(class_count, class_dict):
                        break

# Convert the list of patches and labels into arrays
hsi_samples = np.array(hsi_samples)
lidar_samples = np.array(lidar_samples)
labels = np.array(labels)
print('hsi_samples shape:', hsi_samples.shape)
print('lidar_samples shape:', lidar_samples.shape)
print('labels shape:', labels.shape)
# Out:
# hsi_samples shape: (15029, 9, 9, 144)
# lidar_samples shape: (15029, 9, 9, 1)
# labels shape: (15029,)

# %%
#Avoid overlap of train and test
# Extracting training samples
hsi_training_samples, lidar_training_samples, training_labels = [], [], []
used_indices = []  # To keep track of indices already taken for training samples

for label, class_data in class_dict.items():
    # Get indices of the current class
    class_indices = np.where(labels == label)[0]

    # Randomly shuffle the indices
    np.random.shuffle(class_indices)

    # Take the required number of training samples
    train_indices = class_indices[:class_data["training_sample"]]
    used_indices.extend(train_indices)  # Add these to the used_indices list

    # Append training samples
    hsi_training_samples.extend(hsi_samples[train_indices])
    lidar_training_samples.extend(lidar_samples[train_indices])
    training_labels.extend(labels[train_indices])

# Extracting test samples
hsi_test_samples, lidar_test_samples, test_labels = [], [], []

for label, class_data in class_dict.items():
    class_indices = np.where(labels == label)[0]

    # Exclude indices which were used for training
    test_indices = np.setdiff1d(class_indices, used_indices)

    # Append test samples
    hsi_test_samples.extend(hsi_samples[test_indices])
    lidar_test_samples.extend(lidar_samples[test_indices])
    test_labels.extend(labels[test_indices])

# Convert lists back to numpy arrays
hsi_training_samples = np.array(hsi_training_samples)
lidar_training_samples = np.array(lidar_training_samples)
training_labels = np.array(training_labels)

hsi_test_samples = np.array(hsi_test_samples)
lidar_test_samples = np.array(lidar_test_samples)
test_labels = np.array(test_labels)

# Print shapes to verify
print('hsi_training_samples shape:', hsi_training_samples.shape)
print('lidar_training_samples shape:', lidar_training_samples.shape)
print('training_labels shape:', training_labels.shape)

print('hsi_test_samples shape:', hsi_test_samples.shape)
print('lidar_test_samples shape:', lidar_test_samples.shape)
print('test_labels shape:', test_labels.shape)
# Out:
# hsi_training_samples shape: (2832, 9, 9, 144)
# lidar_training_samples shape: (2832, 9, 9, 1)
# training_labels shape: (2832,)
# hsi_test_samples shape: (12197, 9, 9, 144)
# lidar_test_samples shape: (12197, 9, 9, 1)
# test_labels shape: (12197,)

# %%
hsi_train=hsi_training_samples
lidar_train=lidar_training_samples
y_train=training_labels-1
print('hsi_train_samples shape:', hsi_train.shape)
print('lidar_train_samples shape:', lidar_train.shape)
print('train_labels shape:', y_train.shape)
hsi_test=hsi_test_samples
lidar_test=lidar_test_samples
y_test=test_labels-1
print('hsi_test_samples shape:', hsi_test.shape)
print('lidar_test_samples shape:', lidar_test.shape)
print('y_test shape:', y_test.shape)
# Out:
# hsi_train_samples shape: (2832, 9, 9, 144)
# lidar_train_samples shape: (2832, 9, 9, 1)
# train_labels shape: (2832,)
# hsi_test_samples shape: (12197, 9, 9, 144)
# lidar_test_samples shape: (12197, 9, 9, 1)
# y_test shape: (12197,)

# %%
hsi_train = hsi_train.reshape(hsi_train.shape[0], patch_size*patch_size, hsi_train.shape[-1], 1)
lidar_train = lidar_train.reshape(lidar_train.shape[0], patch_size*patch_size, lidar_train.shape[-1], 1)

hsi_test = hsi_test.reshape(hsi_test.shape[0], patch_size*patch_size, hsi_test.shape[-1], 1)
lidar_test = lidar_test.reshape(lidar_test.shape[0], patch_size*patch_size, lidar_test.shape[-1], 1)

print(hsi_train.shape)
print(lidar_train.shape)

print(hsi_test.shape)
print(lidar_test.shape)
# Out:
# (2832, 81, 144, 1)
# (2832, 81, 1, 1)
# (12197, 81, 144, 1)
# (12197, 81, 1, 1)

# %%
filename = 'UH_ViT_CA_MF_CLS_HSI_LiDAR'
NC = hsi_train.shape[2]
NCLiDAR = lidar_train.shape[2]
n_classes = len(np.unique(training_labels))
print(NC)
print(NCLiDAR)
print(n_classes)
# Out:
# 144
# 1
# 15

# %%
def get_confusion_matrix(y_test, y_pred, name, c, plt_name):
    # print(plt_name)
    df_cm = pd.DataFrame(confusion_matrix(y_test, y_pred), range(c), range(c))
        
    if name == 'UTrento':
        df_cm.columns = ['Buildings', 'Woods', 'Roads', 'Apples', 'Ground', 'Vineyard']
        df_cm = df_cm.rename(index={0: 'Buildings', 1: 'Woods', 2: 'Roads', 3: 'Apples', 4: 'Ground', 5: 'Vineyard'})
    
    elif name == 'UHouston':
        df_cm.columns = ['Healthy grass', 'Stressed grass', 'Synthetic grass', 'Trees', 'Soil', 'Water',  'Residential', 'Commercial', 'Road', 'Highway',
                        'Railway', 'Parking Lot 1', 'Parking Lot 2', 'Tennis Court', 'Running Track']    
        df_cm = df_cm.rename(index={0:'Healthy grass', 1:'Stressed grass', 2:'Synthetic grass', 3:'Trees', 4:'Soil', 5:'Water',  6:'Residential', 7:'Commercial', 8:'Road', 9:'Highway',
                        10:'Railway', 11:'Parking Lot 1', 12:'Parking Lot 2', 13:'Tennis Court', 14:'Running Track'})
    
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'

    plt.figure(figsize=(10, 8))
    sns.set(font_scale=1.2)  # for label size
    heatmap = sns.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 14}, fmt='g', cbar=False)

    heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, ha='right', fontsize=12)
    heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0, fontsize=12)

    plt.tight_layout()
    plt.savefig(f'{plt_name}.png', format='png')
    plt.close()

def AA_andEachClassAccuracy(confusion_matrix):
    counter = confusion_matrix.shape[0]
    list_diag = np.diag(confusion_matrix)
    list_raw_sum = np.sum(confusion_matrix, axis=1)
    each_acc = np.nan_to_num(truediv(list_diag, list_raw_sum))
    average_acc = np.mean(each_acc)
    return each_acc, average_acc

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, in_channels, num_patches, dim, dropout):
        super(PatchEmbedding, self).__init__()

        self.in_channels = in_channels
        self.num_patches = num_patches
        self.dim = dim
        self.dropout = dropout

        self.proj = nn.Conv2d(
            in_channels=in_channels,
            out_channels=in_channels,  # Using num_patches instead of in_channels
            kernel_size=(1,1),
            stride=1,
        )

        self.linear_proj = nn.Linear(in_channels, dim)
        self.norm = nn.LayerNorm(dim)  # Adjusted to apply to each embedding vector

        self.pos_embedding = nn.Parameter(torch.zeros(1, num_patches + 1, dim))
        self.cls_token = nn.Parameter(torch.zeros(1, 1, dim))

        self.dropout_layer = nn.Dropout(dropout)  # Renamed to avoid conflict with attribute name
    
    def forward(self, x):
        B, C, H, W = x.shape
        
        x = self.proj(x)  # Apply convolution
        
        x = x.view(B, C, -1)  # Shape: [B, C, H*W]
        x = x.permute(0, 2, 1)  # Change to [B, spatial_dim, C]
        
        x = self.linear_proj(x)  # Apply linear projection correctly
        
        x = self.norm(x)  # Normalize each embedding vector

        x = torch.cat((self.cls_token.expand(B, -1, -1), x), dim=1)
        x = x + self.pos_embedding
        x = self.dropout_layer(x)
        
        return x

class HSISelfAttention(nn.Module):
    def __init__(self, dim, n_heads, dim_head, dropout):
        super(HSISelfAttention, self).__init__()

        self.dim = dim
        self.dim_head = dim_head
        self.num_heads = n_heads
        self.sqrt_dim_head = math.sqrt(self.dim_head)
        self.dropout_layer = nn.Dropout(dropout)  # Renamed to avoid conflict with attribute name

        # Layer normalization before Q, K, V projections
        self.norm = nn.LayerNorm(dim)

        self.to_q = nn.Linear(dim, dim_head * n_heads, bias=False)
        self.to_k = nn.Linear(dim, dim_head * n_heads, bias=False)
        self.to_v = nn.Linear(dim, dim_head * n_heads, bias=False)

        self.to_out = nn.Linear(n_heads * dim_head, dim)
        self.dropout_layer = nn.Dropout(dropout)  # This line seems duplicated, corrected below

    def forward(self, x):
        B, N, _ = x.size()

        x = self.norm(x)  # Apply normalization before attention

        Q = self.to_q(x)
        K = self.to_k(x)
        V = self.to_v(x)
        
        Q = Q.view(B, N, self.num_heads, self.dim_head).transpose(1, 2)  # [B, num_heads, 144, dim_head]
        K = K.view(B, N, self.num_heads, self.dim_head).transpose(1, 2)  # [B, num_heads, 144, dim_head]
        V = V.view(B, N, self.num_heads, self.dim_head).transpose(1, 2)  # [B, num_heads, 144, dim_head]
        
        # Calculate attention scores
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / self.sqrt_dim_head
        attn_weights = F.softmax(attn_scores, dim=-1)  # [B, num_heads, 144, 144]

        # Apply attention to V
        attn_output = torch.matmul(attn_weights, V)  # [B, num_heads, 144, dim_head]
        attn_output = attn_output.transpose(1, 2).reshape(B, -1, self.num_heads * self.dim_head)  # [B, 144, num_heads * dim_head]

        attn_output = self.dropout_layer(attn_output)
        
        # Project back to the original embedding space
        attn_output = self.to_out(attn_output)  # [B, 144, num_patches]
        
        return attn_output
    
class HSICrossAttention(nn.Module):
    def __init__(self, dim, n_heads, dim_head, dropout):
        super(HSICrossAttention, self).__init__()

        self.dim = dim
        self.dim_head = dim_head
        self.num_heads = n_heads
        self.sqrt_dim_head = math.sqrt(self.dim_head)
        self.dropout_layer = nn.Dropout(dropout)  # Renamed to avoid conflict with attribute name

        # Layer normalization before Q, K, V projections
        self.norm = nn.LayerNorm(dim)

        self.to_q = nn.Linear(dim, dim_head * n_heads, bias=False)
        self.to_k = nn.Linear(dim, dim_head * n_heads, bias=False)
        self.to_v = nn.Linear(dim, dim_head * n_heads, bias=False)

        self.to_out = nn.Linear(n_heads * dim_head, dim)
        self.dropout_layer = nn.Dropout(dropout)  # This line seems duplicated, corrected below

    def forward(self, x1, x2):
        B, N1, _ = x1.size()
        B, N2, _ = x2.size()

        x2 = self.norm(x2)  # Apply normalization before attention

        Q = self.to_q(x1)
        K = self.to_k(x2)
        V = self.to_v(x2)
        
        Q = Q.view(B, N1, self.num_heads, self.dim_head).transpose(1, 2)  # [B, num_heads, 144, dim_head]
        K = K.view(B, N2, self.num_heads, self.dim_head).transpose(1, 2)  # [B, num_heads, 144, dim_head]
        V = V.view(B, N2, self.num_heads, self.dim_head).transpose(1, 2)  # [B, num_heads, 144, dim_head]
        
        # Calculate attention scores
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / self.sqrt_dim_head
        attn_weights = F.softmax(attn_scores, dim=-1)  # [B, num_heads, 144, 144]
        attn_weights = attn_weights.mean(dim=2, keepdim=True)        
        
        # Apply attention to V
        attn_output = torch.matmul(attn_weights, V)  # [B, num_heads, 144, dim_head]
        attn_output = attn_output.transpose(1, 2).reshape(B, -1, self.num_heads * self.dim_head)  # [B, 144, num_heads * dim_head]

        attn_output = self.dropout_layer(attn_output)
        
        # Project back to the original embedding space
        attn_output = self.to_out(attn_output)  # [B, 144, num_patches]
        
        return attn_output

# MLP Module in the Transformer Encoder 
class Mlp(nn.Module):
    def __init__(self, dim, mlp_dim, dropout):
        super(Mlp, self).__init__()
        self.dim = dim
        self.mlp_dim = mlp_dim
        
        self.fc1 = nn.Linear(dim, mlp_dim)
        self.fc2 = nn.Linear(mlp_dim, dim)
        self.act_fn = nn.GELU()
        self.dropout_layer = nn.Dropout(dropout)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.act_fn(x)
        x = self.dropout_layer(x)
        x = self.fc2(x)
        x = self.dropout_layer(x)
        
        return x

# Single Transformer Encoder Block that combines the Self-Attention and MLP layers     
class BlockC(nn.Module):
    def __init__(self, dim, n_heads, dim_head, mlp_dim, dropout):
        super(BlockC, self).__init__()
        self.hidden_size = dim
        self.hidden_dim_size = mlp_dim
        self.attention_norm = nn.LayerNorm(dim)
        self.ffn_norm = nn.LayerNorm(dim)
        self.ffn = Mlp(dim, mlp_dim, dropout)
        self.attn = HSICrossAttention(dim, n_heads, dim_head, dropout)

    def forward(self, x1, x2):
        
        h = x2
        x2 = self.attention_norm(x2)
        x2= self.attn(x1, x2)
        x2 = x2 + h

        h = x2
        x2 = self.ffn_norm(x2)
        x2 = self.ffn(x2)
        x2 = x2 + h
        
        return x2
        
# Transformer Encoder Block with Multi-head Self-Attention repetition    
class TransformerEncoderC(nn.Module):
    def __init__(self, dim, n_heads, dim_head, mlp_dim, dropout, depth):
        super(TransformerEncoderC, self).__init__()
        self.layer = nn.ModuleList()
        self.encoder_norm = nn.LayerNorm(dim)
        for _ in range(depth):
            layer = BlockC(dim, n_heads, dim_head, mlp_dim, dropout)
            self.layer.append(copy.deepcopy(layer))       

    def forward(self, x1, x2):
        for layer_block in self.layer:
            x = layer_block(x1, x2)
            
        encoded = self.encoder_norm(x)

        return encoded

# Single Transformer Encoder Block that combines the Self-Attention and MLP layers     
class Block(nn.Module):
    def __init__(self, dim, n_heads, dim_head, mlp_dim, dropout):
        super(Block, self).__init__()
        self.hidden_size = dim
        self.hidden_dim_size = mlp_dim
        self.attention_norm = nn.LayerNorm(dim)
        self.ffn_norm = nn.LayerNorm(dim)
        self.ffn = Mlp(dim, mlp_dim, dropout)
        self.attn = HSISelfAttention(dim, n_heads, dim_head, dropout)

    def forward(self, x):
        
        h = x
        
        x = self.attention_norm(x)
        x = self.attn(x)
        
        x = x + h

        h = x
        x = self.ffn_norm(x)
        x = self.ffn(x)
        x = x + h
        
        return x

# Transformer Encoder Block with Multi-head Self-Attention repetition    
class TransformerEncoder(nn.Module):
    def __init__(self, dim, n_heads, dim_head, mlp_dim, dropout, depth):
        super(TransformerEncoder, self).__init__()
        self.layer = nn.ModuleList()
        self.encoder_norm = nn.LayerNorm(dim)
        for _ in range(depth):
            layer = Block(dim, n_heads, dim_head, mlp_dim, dropout)
            self.layer.append(copy.deepcopy(layer))       

    def forward(self, x):
        for layer_block in self.layer:
            x = layer_block(x)
            
        encoded = self.encoder_norm(x)

        return encoded
    
# The Final ViT Implementation with cls token from other modalities
class ViT_CA(nn.Module):
    def __init__(self, in_channels=81, num_patches1=144, num_patches2=1, dim=128, n_heads=8, dim_head=64, mlp_dim=256,  depth=3, num_classes=15, dropout=0.4):
        super(ViT_CA, self).__init__()
        
        self.num_patches1 = num_patches1
        self.patch_embedding1 = PatchEmbedding(in_channels, num_patches1, dim, dropout)
        self.patch_embedding2 = PatchEmbedding(in_channels, num_patches2, dim, dropout)
        self.transformer = TransformerEncoder(dim, n_heads, dim_head, mlp_dim, dropout, depth-2)
        self.transformer1 = TransformerEncoderC(dim, n_heads, dim_head, mlp_dim, dropout, depth-1)
        self.linear_head = nn.Linear(dim, num_classes)
        
    def forward(self, x1, x2):
        
        x1 = self.patch_embedding1(x1)
        
        x2 = self.patch_embedding2(x2)
        
        x1 = self.transformer(x1)
        
        x2 = self.transformer(x2)
        
        x1_1 = self.transformer1(x2, x1)
        x2_1 = self.transformer1(x1, x2)
        
        # x = x.mean(dim=1)

        logits_hsi = self.linear_head(x1_1[:,0])
        logits_lid = self.linear_head(x2_1[:,0])
       
        out = (logits_hsi + logits_lid) / 2
        
        return out

# %%
# Convert HSI and label data to PyTorch tensors
hsi_train_tensor = torch.from_numpy(hsi_train.astype(np.float32))  # .permute(0, 1, 2, 3) Shape: (batch, channels, height, width)
lidar_train_tensor = torch.from_numpy(lidar_train.astype(np.float32))  # .permute(0, 1, 2, 3) Shape: (batch, channels, height, width)
training_labels_tensor = torch.from_numpy(y_train.astype(np.int64))

hsi_test_tensor = torch.from_numpy(hsi_test.astype(np.float32))  # Shape: (batch, channels, height, width)
lidar_test_tensor = torch.from_numpy(lidar_test.astype(np.float32))  # Shape: (batch, channels, height, width)
test_labels_tensor = torch.from_numpy(y_test.astype(np.int64))

# Define a dataset class for HSI data
class HyperspectralDataset(Dataset):
    def __init__(self, hsi_data, lidar_data, labels):
        self.hsi_data = hsi_data
        self.lidar_data = lidar_data
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.hsi_data[idx], self.lidar_data[idx], self.labels[idx]

# Create datasets
train_dataset = HyperspectralDataset(hsi_train_tensor, lidar_train_tensor, training_labels_tensor)
# val_dataset = HyperspectralDataset(hsi_samples_val, labels_val)
test_dataset = HyperspectralDataset(hsi_test_tensor, lidar_test_tensor, test_labels_tensor)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False)

print('DataLoaders for training, validation, and testing are ready.')
# Out:
# DataLoaders for training, validation, and testing are ready.

# %%
# model.to(device)

num_epochs = 200  # Set the number of epochs
    
KAPPA = []
OA = []
AA = []                
ELEMENT_ACC = np.zeros((3, n_classes))

for iterNum in range(3):
    model = ViT_CA(in_channels=81, num_patches1=NC, num_patches2=NCLiDAR, dim=128, n_heads=8, dim_head=64, mlp_dim=256,  depth=3, num_classes=n_classes, dropout=0.1).cuda()
    summary(model, [(81, NC, 1), (81, NCLiDAR, 1)])
    model.to(device)
    
    # Define the optimizer
    optimizer = optim.Adam(model.parameters(), lr=5e-4)  # Adjust learning rate as needed

    # Define learning rate scheduler
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)  # Adjust parameters as needed

    # Instantiate the loss function
    criterion = nn.CrossEntropyLoss()
    
    # Training loop
    best_test_acc = float('-inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    
    torch.cuda.synchronize()
    
    start = time.time()
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        running_loss = 0.0

        # Training phase
        for batch_idx, (hsi_batch, lidar_batch, label_batch) in enumerate(train_loader):
            hsi_batch = hsi_batch.to(device)
            lidar_batch = lidar_batch.to(device)
            label_batch = label_batch.to(device)

            # Forward pass
            outputs = model(hsi_batch, lidar_batch)
        
            # Loss calculation
            loss = criterion(outputs, label_batch)
        
            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_train_loss = running_loss / len(train_loader)

        # Compute training accuracy
        model.eval()
        with torch.no_grad():
            correct_train = 0
            total_train = 0
            for hsi_batch, lidar_batch, label_batch in train_loader:
                hsi_batch = hsi_batch.to(device)
                lidar_batch = lidar_batch.to(device)
                label_batch = label_batch.to(device)
                outputs = model(hsi_batch, lidar_batch)
                _, predicted = torch.max(outputs, 1)
                total_train += label_batch.size(0)
                correct_train += (predicted == label_batch).sum().item()

        train_accuracy = correct_train / total_train * 100

        # Validation phase
        model.eval()  # Set model to evaluation mode
        test_loss = 0.0
        correct_test = 0
        total_test = 0
        with torch.no_grad():  # No need to track gradients during validation
            for hsi_batch, lidar_batch, label_batch in test_loader:
                hsi_batch = hsi_batch.to(device)
                lidar_batch = lidar_batch.to(device)
                label_batch = label_batch.to(device)

                outputs = model(hsi_batch, lidar_batch)
                loss = criterion(outputs, label_batch)
                test_loss += loss.item()            

                _, predicted = torch.max(outputs, 1)
                total_test += label_batch.size(0)
                correct_test += (predicted == label_batch).sum().item()

        avg_test_loss = test_loss / len(test_loader)
        test_accuracy = correct_test / total_test * 100

        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}%, Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%')

        # Check if this is the best model so far
        if test_accuracy > best_test_acc:
            print('\n')
            print(f'Test accuracy increased ({best_test_acc:.4f} --> {test_accuracy:.4f}). Saving model ...')
            best_test_acc = test_accuracy
            best_model_wts = copy.deepcopy(model.state_dict())
            # Save model weights
            torch.save(model.state_dict(), 'best_model_'+str(filename)+'_Iter_'+str(iterNum)+'.pth')

    end = time.time()
    print("\n")
    print('\nThe train time (in seconds) is:', end - start) 
                            
    # Load the best model weights
    model.load_state_dict(best_model_wts)
    # Test the model
    model.eval()
    test_loss = 0.0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for hsi_batch, lidar_batch, label_batch in test_loader:
            hsi_batch = hsi_batch.to(device)
            lidar_batch = lidar_batch.to(device)
            label_batch = label_batch.to(device)

            outputs = model(hsi_batch, lidar_batch)
            loss = criterion(outputs, label_batch)
            test_loss += loss.item()

            preds = torch.max(outputs, 1)[1].cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(label_batch.cpu().numpy())

    # Calculate average test loss
    avg_test_loss = test_loss / len(test_loader)
    print(f'Test Loss: {avg_test_loss:.4f}')

    # Convert lists to numpy arrays for evaluation metrics
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)

    get_confusion_matrix(all_labels, all_preds, datasetname, n_classes, filename + str('_') + str(iterNum))
    
    # Evaluate metrics
    oa = accuracy_score(all_labels, all_preds)
    confusion = confusion_matrix(all_labels, all_preds)
    each_acc, aa = AA_andEachClassAccuracy(confusion)
    kappa = cohen_kappa_score(all_labels, all_preds)    
                    
    KAPPA.append(kappa*100)
    OA.append(oa*100)
    AA.append(aa*100)
    ELEMENT_ACC[iterNum, :] = each_acc*100
    # torch.save(model, datasetname+'/best_model_'+filename+'_Iter'+str(iterNum)+'.pt')
print("\n")
record.record_output(OA, AA, KAPPA, ELEMENT_ACC,'./' + datasetname+'/'+filename+'_Report_' + datasetname +'.txt')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 81, 144, 1]           6,642
#             Linear-2             [-1, 144, 128]          10,496
#          LayerNorm-3             [-1, 144, 128]             256
#            Dropout-4             [-1, 145, 128]               0
#     PatchEmbedding-5             [-1, 145, 128]               0
#             Conv2d-6             [-1, 81, 1, 1]           6,642
#             Linear-7               [-1, 1, 128]          10,496
#          LayerNorm-8               [-1, 1, 128]             256
#            Dropout-9               [-1, 2, 128]               0
#    PatchEmbedding-10               [-1, 2, 128]               0
#         LayerNorm-11             [-1, 145, 128]             256
#         LayerNorm-12             [-1, 145, 128]             256
#            Linear-13             [-1, 145, 512]          65,536
#            Linear-14             [-1, 145, 512]          65,536
#            Linear-15             [-1, 145, 512]          65,536
#           Dropout-16             [-1, 145, 512]               0
#            Linear-17             [-1, 145, 128]          65,664
#  HSISelfAttention-18             [-1, 145, 128]               0
#         LayerNorm-19             [-1, 145, 128]             256
#            Linear-20             [-1, 145, 256]          33,024
#              GELU-21             [-1, 145, 256]               0
#           Dropout-22             [-1, 145, 256]               0
#            Linear-23             [-1, 145, 128]          32,896
#           Dropout-24             [-1, 145, 128]               0
#               Mlp-25             [-1, 145, 128]               0
#             Block-26             [-1, 145, 128]               0
#         LayerNorm-27             [-1, 145, 128]             256
# TransformerEncoder-28             [-1, 145, 128]               0
#         LayerNorm-29               [-1, 2, 128]             256
#         LayerNorm-30               [-1, 2, 128]             256
#            Linear-31               [-1, 2, 512]          65,536
#            Linear-32               [-1, 2, 512]          65,536
#            Linear-33               [-1, 2, 512]          65,536
#           Dropout-34               [-1, 2, 512]               0
#            Linear-35               [-1, 2, 128]          65,664
#  HSISelfAttention-36               [-1, 2, 128]               0
#         LayerNorm-37               [-1, 2, 128]             256
#            Linear-38               [-1, 2, 256]          33,024
#              GELU-39               [-1, 2, 256]               0
#           Dropout-40               [-1, 2, 256]               0
#            Linear-41               [-1, 2, 128]          32,896
#           Dropout-42               [-1, 2, 128]               0
#               Mlp-43               [-1, 2, 128]               0
#             Block-44               [-1, 2, 128]               0
#         LayerNorm-45               [-1, 2, 128]             256
# TransformerEncoder-46               [-1, 2, 128]               0
#         LayerNorm-47             [-1, 145, 128]             256
#         LayerNorm-48             [-1, 145, 128]             256
#            Linear-49               [-1, 2, 512]          65,536
#            Linear-50             [-1, 145, 512]          65,536
#            Linear-51             [-1, 145, 512]          65,536
#           Dropout-52               [-1, 1, 512]               0
#            Linear-53               [-1, 1, 128]          65,664
# HSICrossAttention-54               [-1, 1, 128]               0
#         LayerNorm-55             [-1, 145, 128]             256
#            Linear-56             [-1, 145, 256]          33,024
#              GELU-57             [-1, 145, 256]               0
#           Dropout-58             [-1, 145, 256]               0
#            Linear-59             [-1, 145, 128]          32,896
#           Dropout-60             [-1, 145, 128]               0
#               Mlp-61             [-1, 145, 128]               0
#            BlockC-62             [-1, 145, 128]               0
#         LayerNorm-63             [-1, 145, 128]             256
#         LayerNorm-64             [-1, 145, 128]             256
#            Linear-65               [-1, 2, 512]          65,536
#            Linear-66             [-1, 145, 512]          65,536
#            Linear-67             [-1, 145, 512]          65,536
#           Dropout-68               [-1, 1, 512]               0
#            Linear-69               [-1, 1, 128]          65,664
# HSICrossAttention-70               [-1, 1, 128]               0
#         LayerNorm-71             [-1, 145, 128]             256
#            Linear-72             [-1, 145, 256]          33,024
#              GELU-73             [-1, 145, 256]               0
#           Dropout-74             [-1, 145, 256]               0
#            Linear-75             [-1, 145, 128]          32,896
#           Dropout-76             [-1, 145, 128]               0
#               Mlp-77             [-1, 145, 128]               0
#            BlockC-78             [-1, 145, 128]               0
#         LayerNorm-79             [-1, 145, 128]             256
# TransformerEncoderC-80             [-1, 145, 128]               0
#         LayerNorm-81               [-1, 2, 128]             256
#         LayerNorm-82               [-1, 2, 128]             256
#            Linear-83             [-1, 145, 512]          65,536
#            Linear-84               [-1, 2, 512]          65,536
#            Linear-85               [-1, 2, 512]          65,536
#           Dropout-86               [-1, 1, 512]               0
#            Linear-87               [-1, 1, 128]          65,664
# HSICrossAttention-88               [-1, 1, 128]               0
#         LayerNorm-89               [-1, 2, 128]             256
#            Linear-90               [-1, 2, 256]          33,024
#              GELU-91               [-1, 2, 256]               0
#           Dropout-92               [-1, 2, 256]               0
#            Linear-93               [-1, 2, 128]          32,896
#           Dropout-94               [-1, 2, 128]               0
#               Mlp-95               [-1, 2, 128]               0
#            BlockC-96               [-1, 2, 128]               0
#         LayerNorm-97               [-1, 2, 128]             256
#         LayerNorm-98               [-1, 2, 128]             256
#            Linear-99             [-1, 145, 512]          65,536
#           Linear-100               [-1, 2, 512]          65,536
#           Linear-101               [-1, 2, 512]          65,536
#          Dropout-102               [-1, 1, 512]               0
#           Linear-103               [-1, 1, 128]          65,664
# HSICrossAttention-104               [-1, 1, 128]               0
#        LayerNorm-105               [-1, 2, 128]             256
#           Linear-106               [-1, 2, 256]          33,024
#             GELU-107               [-1, 2, 256]               0
#          Dropout-108               [-1, 2, 256]               0
#           Linear-109               [-1, 2, 128]          32,896
#          Dropout-110               [-1, 2, 128]               0
#              Mlp-111               [-1, 2, 128]               0
#           BlockC-112               [-1, 2, 128]               0
#        LayerNorm-113               [-1, 2, 128]             256
# TransformerEncoderC-114               [-1, 2, 128]               0
#           Linear-115                   [-1, 15]           1,935
#           Linear-116                   [-1, 15]           1,935
# ================================================================
# Total params: 2,013,442
# Trainable params: 2,013,442
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.60
# Forward/backward pass size (MB): 12.89
# Params size (MB): 7.68
# Estimated Total Size (MB): 24.17
# ----------------------------------------------------------------
# Epoch [1/200], Training Loss: 2.7284, Training Accuracy: 11.65%, Test Loss: 2.6813, Test Accuracy: 9.83%
#
#
# Test accuracy increased (-inf --> 9.8303). Saving model ...
# Epoch [2/200], Training Loss: 2.5380, Training Accuracy: 26.91%, Test Loss: 2.4018, Test Accuracy: 22.03%
#
#
# Test accuracy increased (9.8303 --> 22.0300). Saving model ...
# Epoch [3/200], Training Loss: 2.2000, Training Accuracy: 26.66%, Test Loss: 2.2667, Test Accuracy: 22.94%
#
#
# Test accuracy increased (22.0300 --> 22.9401). Saving model ...
# Epoch [4/200], Training Loss: 1.9441, Training Accuracy: 48.06%, Test Loss: 1.8448, Test Accuracy: 39.76%
#
#
# Test accuracy increased (22.9401 --> 39.7557). Saving model ...
# Epoch [5/200], Training Loss: 1.6181, Training Accuracy: 53.74%, Test Loss: 1.6668, Test Accuracy: 43.99%
#
#
# Test accuracy increased (39.7557 --> 43.9944). Saving model ...
# Epoch [6/200], Training Loss: 1.3829, Training Accuracy: 62.15%, Test Loss: 1.5180, Test Accuracy: 50.00%
#
#
# Test accuracy increased (43.9944 --> 49.9959). Saving model ...
# Epoch [7/200], Training Loss: 1.2040, Training Accuracy: 67.02%, Test Loss: 1.3345, Test Accuracy: 55.73%
#
#
# Test accuracy increased (49.9959 --> 55.7268). Saving model ...
# Epoch [8/200], Training Loss: 1.1199, Training Accuracy: 68.26%, Test Loss: 1.2887, Test Accuracy: 55.51%
# Epoch [9/200], Training Loss: 0.9932, Training Accuracy: 70.06%, Test Loss: 1.2366, Test Accuracy: 57.15%
#
#
# Test accuracy increased (55.7268 --> 57.1452). Saving model ...
# Epoch [10/200], Training Loss: 0.9040, Training Accuracy: 69.00%, Test Loss: 1.3430, Test Accuracy: 56.28%
# Epoch [11/200], Training Loss: 0.7698, Training Accuracy: 76.13%, Test Loss: 1.1929, Test Accuracy: 59.76%
#
#
# Test accuracy increased (57.1452 --> 59.7606). Saving model ...
# Epoch [12/200], Training Loss: 0.7342, Training Accuracy: 73.52%, Test Loss: 1.1693, Test Accuracy: 60.15%
#
#
# Test accuracy increased (59.7606 --> 60.1541). Saving model ...
# Epoch [13/200], Training Loss: 0.6675, Training Accuracy: 79.80%, Test Loss: 1.0386, Test Accuracy: 64.70%
#
#
# Test accuracy increased (60.1541 --> 64.7044). Saving model ...
# Epoch [14/200], Training Loss: 0.6579, Training Accuracy: 80.61%, Test Loss: 0.9997, Test Accuracy: 66.43%
#
#
# Test accuracy increased (64.7044 --> 66.4262). Saving model ...
# Epoch [15/200], Training Loss: 0.5422, Training Accuracy: 87.25%, Test Loss: 0.8817, Test Accuracy: 69.48%
#
#
# Test accuracy increased (66.4262 --> 69.4843). Saving model ...
# Epoch [16/200], Training Loss: 0.5301, Training Accuracy: 83.90%, Test Loss: 0.9495, Test Accuracy: 67.90%
# Epoch [17/200], Training Loss: 0.4882, Training Accuracy: 85.95%, Test Loss: 0.9055, Test Accuracy: 69.34%
# Epoch [18/200], Training Loss: 0.4361, Training Accuracy: 92.13%, Test Loss: 0.7426, Test Accuracy: 75.64%
#
#
# Test accuracy increased (69.4843 --> 75.6416). Saving model ...
# Epoch [19/200], Training Loss: 0.3898, Training Accuracy: 90.43%, Test Loss: 0.7551, Test Accuracy: 74.85%
# Epoch [20/200], Training Loss: 0.3432, Training Accuracy: 90.01%, Test Loss: 0.8240, Test Accuracy: 71.69%
# Epoch [21/200], Training Loss: 0.3403, Training Accuracy: 91.77%, Test Loss: 0.7699, Test Accuracy: 73.94%
# Epoch [22/200], Training Loss: 0.2910, Training Accuracy: 93.64%, Test Loss: 0.7168, Test Accuracy: 76.35%
#
#
# Test accuracy increased (75.6416 --> 76.3466). Saving model ...
# Epoch [23/200], Training Loss: 0.3106, Training Accuracy: 91.49%, Test Loss: 0.7406, Test Accuracy: 75.48%
# Epoch [24/200], Training Loss: 0.2864, Training Accuracy: 94.81%, Test Loss: 0.6936, Test Accuracy: 77.59%
#
#
# Test accuracy increased (76.3466 --> 77.5929). Saving model ...
# Epoch [25/200], Training Loss: 0.2183, Training Accuracy: 95.34%, Test Loss: 0.6715, Test Accuracy: 78.33%
#
#
# Test accuracy increased (77.5929 --> 78.3307). Saving model ...
# Epoch [26/200], Training Loss: 0.2399, Training Accuracy: 94.14%, Test Loss: 0.7099, Test Accuracy: 76.54%
# Epoch [27/200], Training Loss: 0.1755, Training Accuracy: 97.18%, Test Loss: 0.6501, Test Accuracy: 79.36%
#
#
# Test accuracy increased (78.3307 --> 79.3556). Saving model ...
# Epoch [28/200], Training Loss: 0.1812, Training Accuracy: 94.46%, Test Loss: 0.7338, Test Accuracy: 77.38%
# Epoch [29/200], Training Loss: 0.1601, Training Accuracy: 95.87%, Test Loss: 0.7090, Test Accuracy: 77.65%
# Epoch [30/200], Training Loss: 0.1583, Training Accuracy: 96.05%, Test Loss: 0.6836, Test Accuracy: 78.99%
# Epoch [31/200], Training Loss: 0.1800, Training Accuracy: 94.46%, Test Loss: 0.7612, Test Accuracy: 76.44%
# Epoch [32/200], Training Loss: 0.2402, Training Accuracy: 96.79%, Test Loss: 0.6846, Test Accuracy: 78.24%
# Epoch [33/200], Training Loss: 0.2263, Training Accuracy: 94.31%, Test Loss: 0.7343, Test Accuracy: 77.24%
# Epoch [34/200], Training Loss: 0.2185, Training Accuracy: 97.14%, Test Loss: 0.6217, Test Accuracy: 80.48%
#
#
# Test accuracy increased (79.3556 --> 80.4788). Saving model ...
# Epoch [35/200], Training Loss: 0.1397, Training Accuracy: 98.55%, Test Loss: 0.5768, Test Accuracy: 82.40%
#
#
# Test accuracy increased (80.4788 --> 82.3973). Saving model ...
# Epoch [36/200], Training Loss: 0.1018, Training Accuracy: 97.81%, Test Loss: 0.6469, Test Accuracy: 81.01%
# Epoch [37/200], Training Loss: 0.1359, Training Accuracy: 95.90%, Test Loss: 0.7000, Test Accuracy: 78.71%
# Epoch [38/200], Training Loss: 0.1337, Training Accuracy: 96.75%, Test Loss: 0.7103, Test Accuracy: 79.51%
# Epoch [39/200], Training Loss: 0.1534, Training Accuracy: 97.35%, Test Loss: 0.7218, Test Accuracy: 78.27%
# Epoch [40/200], Training Loss: 0.1073, Training Accuracy: 98.27%, Test Loss: 0.6846, Test Accuracy: 79.77%
# Epoch [41/200], Training Loss: 0.0747, Training Accuracy: 98.48%, Test Loss: 0.6815, Test Accuracy: 80.50%
# Epoch [42/200], Training Loss: 0.0827, Training Accuracy: 97.03%, Test Loss: 0.6886, Test Accuracy: 80.25%
# Epoch [43/200], Training Loss: 0.1563, Training Accuracy: 98.83%, Test Loss: 0.6586, Test Accuracy: 80.55%
# Epoch [44/200], Training Loss: 0.0837, Training Accuracy: 98.06%, Test Loss: 0.6894, Test Accuracy: 80.36%
# Epoch [45/200], Training Loss: 0.0806, Training Accuracy: 97.07%, Test Loss: 0.7788, Test Accuracy: 78.95%
# Epoch [46/200], Training Loss: 0.1165, Training Accuracy: 97.35%, Test Loss: 0.7726, Test Accuracy: 78.89%
# Epoch [47/200], Training Loss: 0.0946, Training Accuracy: 98.69%, Test Loss: 0.7101, Test Accuracy: 80.31%
# Epoch [48/200], Training Loss: 0.1343, Training Accuracy: 97.63%, Test Loss: 0.7751, Test Accuracy: 79.01%
# Epoch [49/200], Training Loss: 0.1191, Training Accuracy: 98.94%, Test Loss: 0.6306, Test Accuracy: 81.69%
# Epoch [50/200], Training Loss: 0.0640, Training Accuracy: 99.29%, Test Loss: 0.6326, Test Accuracy: 82.49%
#
#
# Test accuracy increased (82.3973 --> 82.4875). Saving model ...
# Epoch [51/200], Training Loss: 0.0425, Training Accuracy: 97.92%, Test Loss: 0.7697, Test Accuracy: 79.93%
# Epoch [52/200], Training Loss: 0.0583, Training Accuracy: 99.44%, Test Loss: 0.6200, Test Accuracy: 82.94%
#
#
# Test accuracy increased (82.4875 --> 82.9384). Saving model ...
# Epoch [53/200], Training Loss: 0.1201, Training Accuracy: 97.53%, Test Loss: 0.7254, Test Accuracy: 79.63%
# Epoch [54/200], Training Loss: 0.1180, Training Accuracy: 98.94%, Test Loss: 0.6357, Test Accuracy: 82.50%
# Epoch [55/200], Training Loss: 0.0788, Training Accuracy: 98.09%, Test Loss: 0.7099, Test Accuracy: 81.01%
# Epoch [56/200], Training Loss: 0.0753, Training Accuracy: 99.89%, Test Loss: 0.5887, Test Accuracy: 83.75%
#
#
# Test accuracy increased (82.9384 --> 83.7501). Saving model ...
# Epoch [57/200], Training Loss: 0.0335, Training Accuracy: 99.08%, Test Loss: 0.6826, Test Accuracy: 82.53%
# Epoch [58/200], Training Loss: 0.0279, Training Accuracy: 99.54%, Test Loss: 0.5986, Test Accuracy: 83.95%
#
#
# Test accuracy increased (83.7501 --> 83.9469). Saving model ...
# Epoch [59/200], Training Loss: 0.0398, Training Accuracy: 98.62%, Test Loss: 0.7221, Test Accuracy: 80.68%
# Epoch [60/200], Training Loss: 0.0594, Training Accuracy: 99.19%, Test Loss: 0.6188, Test Accuracy: 83.54%
# Epoch [61/200], Training Loss: 0.0341, Training Accuracy: 99.61%, Test Loss: 0.6392, Test Accuracy: 83.00%
# Epoch [62/200], Training Loss: 0.0214, Training Accuracy: 99.65%, Test Loss: 0.6083, Test Accuracy: 84.00%
#
#
# Test accuracy increased (83.9469 --> 83.9961). Saving model ...
# Epoch [63/200], Training Loss: 0.0219, Training Accuracy: 99.93%, Test Loss: 0.6354, Test Accuracy: 83.64%
# Epoch [64/200], Training Loss: 0.0517, Training Accuracy: 98.59%, Test Loss: 0.6953, Test Accuracy: 81.90%
# Epoch [65/200], Training Loss: 0.0621, Training Accuracy: 98.27%, Test Loss: 0.7306, Test Accuracy: 80.71%
# Epoch [66/200], Training Loss: 0.1082, Training Accuracy: 95.69%, Test Loss: 0.9594, Test Accuracy: 77.77%
# Epoch [67/200], Training Loss: 0.2904, Training Accuracy: 95.62%, Test Loss: 0.8228, Test Accuracy: 77.60%
# Epoch [68/200], Training Loss: 0.2200, Training Accuracy: 96.61%, Test Loss: 0.7765, Test Accuracy: 77.49%
# Epoch [69/200], Training Loss: 0.1086, Training Accuracy: 97.21%, Test Loss: 0.7291, Test Accuracy: 80.81%
# Epoch [70/200], Training Loss: 0.0948, Training Accuracy: 99.47%, Test Loss: 0.6263, Test Accuracy: 83.01%
# Epoch [71/200], Training Loss: 0.0813, Training Accuracy: 99.33%, Test Loss: 0.6820, Test Accuracy: 82.09%
# Epoch [72/200], Training Loss: 0.1343, Training Accuracy: 98.31%, Test Loss: 0.7394, Test Accuracy: 80.90%
# Epoch [73/200], Training Loss: 0.0770, Training Accuracy: 98.06%, Test Loss: 0.7178, Test Accuracy: 81.71%
# Epoch [74/200], Training Loss: 0.0704, Training Accuracy: 99.54%, Test Loss: 0.6580, Test Accuracy: 81.98%
# Epoch [75/200], Training Loss: 0.0360, Training Accuracy: 99.79%, Test Loss: 0.6295, Test Accuracy: 83.65%
# Epoch [76/200], Training Loss: 0.0366, Training Accuracy: 99.44%, Test Loss: 0.6608, Test Accuracy: 83.64%
# Epoch [77/200], Training Loss: 0.0244, Training Accuracy: 99.86%, Test Loss: 0.6120, Test Accuracy: 85.13%
#
#
# Test accuracy increased (83.9961 --> 85.1275). Saving model ...
# Epoch [78/200], Training Loss: 0.0141, Training Accuracy: 99.89%, Test Loss: 0.5555, Test Accuracy: 85.37%
#
#
# Test accuracy increased (85.1275 --> 85.3735). Saving model ...
# Epoch [79/200], Training Loss: 0.0321, Training Accuracy: 99.89%, Test Loss: 0.6510, Test Accuracy: 83.74%
# Epoch [80/200], Training Loss: 0.0269, Training Accuracy: 99.61%, Test Loss: 0.6281, Test Accuracy: 84.15%
# Epoch [81/200], Training Loss: 0.0260, Training Accuracy: 99.93%, Test Loss: 0.5721, Test Accuracy: 85.32%
# Epoch [82/200], Training Loss: 0.0218, Training Accuracy: 99.82%, Test Loss: 0.5963, Test Accuracy: 84.41%
# Epoch [83/200], Training Loss: 0.0227, Training Accuracy: 99.15%, Test Loss: 0.6819, Test Accuracy: 82.85%
# Epoch [84/200], Training Loss: 0.0218, Training Accuracy: 99.93%, Test Loss: 0.5875, Test Accuracy: 85.16%
# Epoch [85/200], Training Loss: 0.0089, Training Accuracy: 99.75%, Test Loss: 0.6049, Test Accuracy: 85.42%
#
#
# Test accuracy increased (85.3735 --> 85.4226). Saving model ...
# Epoch [86/200], Training Loss: 0.0156, Training Accuracy: 99.93%, Test Loss: 0.6767, Test Accuracy: 83.56%
# Epoch [87/200], Training Loss: 0.0343, Training Accuracy: 99.51%, Test Loss: 0.6455, Test Accuracy: 84.09%
# Epoch [88/200], Training Loss: 0.0762, Training Accuracy: 97.32%, Test Loss: 0.8944, Test Accuracy: 78.43%
# Epoch [89/200], Training Loss: 0.1481, Training Accuracy: 92.44%, Test Loss: 1.1107, Test Accuracy: 75.07%
# Epoch [90/200], Training Loss: 0.1703, Training Accuracy: 92.30%, Test Loss: 1.0684, Test Accuracy: 73.25%
# Epoch [91/200], Training Loss: 0.1584, Training Accuracy: 96.75%, Test Loss: 0.8751, Test Accuracy: 78.00%
# Epoch [92/200], Training Loss: 0.1199, Training Accuracy: 98.52%, Test Loss: 0.7249, Test Accuracy: 81.73%
# Epoch [93/200], Training Loss: 0.0922, Training Accuracy: 99.12%, Test Loss: 0.6489, Test Accuracy: 83.41%
# Epoch [94/200], Training Loss: 0.0538, Training Accuracy: 99.47%, Test Loss: 0.6471, Test Accuracy: 83.54%
# Epoch [95/200], Training Loss: 0.0198, Training Accuracy: 99.89%, Test Loss: 0.5559, Test Accuracy: 85.97%
#
#
# Test accuracy increased (85.4226 --> 85.9720). Saving model ...
# Epoch [96/200], Training Loss: 0.0187, Training Accuracy: 99.93%, Test Loss: 0.6389, Test Accuracy: 84.30%
# Epoch [97/200], Training Loss: 0.0099, Training Accuracy: 100.00%, Test Loss: 0.5590, Test Accuracy: 86.43%
#
#
# Test accuracy increased (85.9720 --> 86.4311). Saving model ...
# Epoch [98/200], Training Loss: 0.0104, Training Accuracy: 100.00%, Test Loss: 0.5625, Test Accuracy: 86.48%
#
#
# Test accuracy increased (86.4311 --> 86.4803). Saving model ...
# Epoch [99/200], Training Loss: 0.0035, Training Accuracy: 100.00%, Test Loss: 0.5501, Test Accuracy: 86.42%
# Epoch [100/200], Training Loss: 0.0223, Training Accuracy: 99.36%, Test Loss: 0.6017, Test Accuracy: 84.76%
# Epoch [101/200], Training Loss: 0.0554, Training Accuracy: 99.54%, Test Loss: 0.6522, Test Accuracy: 83.82%
# Epoch [102/200], Training Loss: 0.0626, Training Accuracy: 99.36%, Test Loss: 0.7098, Test Accuracy: 83.19%
# Epoch [103/200], Training Loss: 0.0610, Training Accuracy: 97.78%, Test Loss: 0.7555, Test Accuracy: 81.59%
# Epoch [104/200], Training Loss: 0.0902, Training Accuracy: 99.01%, Test Loss: 0.7264, Test Accuracy: 82.36%
# Epoch [105/200], Training Loss: 0.0511, Training Accuracy: 99.40%, Test Loss: 0.7320, Test Accuracy: 81.98%
# Epoch [106/200], Training Loss: 0.0344, Training Accuracy: 99.68%, Test Loss: 0.6658, Test Accuracy: 83.89%
# Epoch [107/200], Training Loss: 0.0181, Training Accuracy: 99.75%, Test Loss: 0.6371, Test Accuracy: 84.32%
# Epoch [108/200], Training Loss: 0.0422, Training Accuracy: 99.65%, Test Loss: 0.6575, Test Accuracy: 84.00%
# Epoch [109/200], Training Loss: 0.0303, Training Accuracy: 99.82%, Test Loss: 0.6810, Test Accuracy: 83.77%
# Epoch [110/200], Training Loss: 0.0410, Training Accuracy: 99.44%, Test Loss: 0.6671, Test Accuracy: 83.42%
# Epoch [111/200], Training Loss: 0.0815, Training Accuracy: 96.40%, Test Loss: 0.9705, Test Accuracy: 77.54%
# Epoch [112/200], Training Loss: 0.1615, Training Accuracy: 98.41%, Test Loss: 0.8101, Test Accuracy: 80.72%
# Epoch [113/200], Training Loss: 0.0819, Training Accuracy: 99.51%, Test Loss: 0.7081, Test Accuracy: 83.04%
# Epoch [114/200], Training Loss: 0.0604, Training Accuracy: 98.87%, Test Loss: 0.7442, Test Accuracy: 81.48%
# Epoch [115/200], Training Loss: 0.0548, Training Accuracy: 99.29%, Test Loss: 0.6806, Test Accuracy: 83.18%
# Epoch [116/200], Training Loss: 0.0466, Training Accuracy: 99.68%, Test Loss: 0.6733, Test Accuracy: 84.08%
# Epoch [117/200], Training Loss: 0.0241, Training Accuracy: 99.86%, Test Loss: 0.6140, Test Accuracy: 85.19%
# Epoch [118/200], Training Loss: 0.0202, Training Accuracy: 99.86%, Test Loss: 0.5882, Test Accuracy: 85.56%
# Epoch [119/200], Training Loss: 0.0195, Training Accuracy: 99.86%, Test Loss: 0.5907, Test Accuracy: 85.78%
# Epoch [120/200], Training Loss: 0.0125, Training Accuracy: 99.96%, Test Loss: 0.6248, Test Accuracy: 85.37%
# Epoch [121/200], Training Loss: 0.0049, Training Accuracy: 99.93%, Test Loss: 0.5667, Test Accuracy: 86.37%
# Epoch [122/200], Training Loss: 0.0142, Training Accuracy: 99.82%, Test Loss: 0.6883, Test Accuracy: 84.55%
# Epoch [123/200], Training Loss: 0.0118, Training Accuracy: 100.00%, Test Loss: 0.5800, Test Accuracy: 86.46%
# Epoch [124/200], Training Loss: 0.0032, Training Accuracy: 99.96%, Test Loss: 0.5715, Test Accuracy: 86.64%
#
#
# Test accuracy increased (86.4803 --> 86.6361). Saving model ...
# Epoch [125/200], Training Loss: 0.0028, Training Accuracy: 100.00%, Test Loss: 0.5638, Test Accuracy: 87.14%
#
#
# Test accuracy increased (86.6361 --> 87.1444). Saving model ...
# Epoch [126/200], Training Loss: 0.0032, Training Accuracy: 99.96%, Test Loss: 0.5949, Test Accuracy: 86.56%
# Epoch [127/200], Training Loss: 0.0018, Training Accuracy: 100.00%, Test Loss: 0.5658, Test Accuracy: 87.10%
# Epoch [128/200], Training Loss: 0.0013, Training Accuracy: 100.00%, Test Loss: 0.5739, Test Accuracy: 87.19%
#
#
# Test accuracy increased (87.1444 --> 87.1936). Saving model ...
# Epoch [129/200], Training Loss: 0.0009, Training Accuracy: 100.00%, Test Loss: 0.5698, Test Accuracy: 87.37%
#
#
# Test accuracy increased (87.1936 --> 87.3657). Saving model ...
# Epoch [130/200], Training Loss: 0.0009, Training Accuracy: 100.00%, Test Loss: 0.5647, Test Accuracy: 87.53%
#
#
# Test accuracy increased (87.3657 --> 87.5297). Saving model ...
# Epoch [131/200], Training Loss: 0.0011, Training Accuracy: 99.96%, Test Loss: 0.5583, Test Accuracy: 87.41%
# Epoch [132/200], Training Loss: 0.0022, Training Accuracy: 99.93%, Test Loss: 0.5668, Test Accuracy: 87.13%
# Epoch [133/200], Training Loss: 0.0078, Training Accuracy: 99.89%, Test Loss: 0.6710, Test Accuracy: 85.37%
# Epoch [134/200], Training Loss: 0.0491, Training Accuracy: 96.96%, Test Loss: 0.9668, Test Accuracy: 78.58%
# Epoch [135/200], Training Loss: 0.2144, Training Accuracy: 95.37%, Test Loss: 0.9349, Test Accuracy: 77.06%
# Epoch [136/200], Training Loss: 0.1453, Training Accuracy: 95.73%, Test Loss: 0.8287, Test Accuracy: 78.66%
# Epoch [137/200], Training Loss: 0.2052, Training Accuracy: 96.43%, Test Loss: 0.7837, Test Accuracy: 79.86%
# Epoch [138/200], Training Loss: 0.1570, Training Accuracy: 98.27%, Test Loss: 0.7379, Test Accuracy: 81.40%
# Epoch [139/200], Training Loss: 0.1023, Training Accuracy: 98.52%, Test Loss: 0.6780, Test Accuracy: 82.40%
# Epoch [140/200], Training Loss: 0.0533, Training Accuracy: 99.54%, Test Loss: 0.6798, Test Accuracy: 83.36%
# Epoch [141/200], Training Loss: 0.0274, Training Accuracy: 99.82%, Test Loss: 0.6164, Test Accuracy: 84.68%
# Epoch [142/200], Training Loss: 0.0144, Training Accuracy: 99.82%, Test Loss: 0.5524, Test Accuracy: 87.07%
# Epoch [143/200], Training Loss: 0.0078, Training Accuracy: 99.93%, Test Loss: 0.5427, Test Accuracy: 86.76%
# Epoch [144/200], Training Loss: 0.0172, Training Accuracy: 99.82%, Test Loss: 0.5927, Test Accuracy: 85.92%
# Epoch [145/200], Training Loss: 0.0114, Training Accuracy: 99.93%, Test Loss: 0.5777, Test Accuracy: 86.52%
# Epoch [146/200], Training Loss: 0.0068, Training Accuracy: 99.96%, Test Loss: 0.5895, Test Accuracy: 86.23%
# Epoch [147/200], Training Loss: 0.0080, Training Accuracy: 99.96%, Test Loss: 0.6102, Test Accuracy: 86.16%
# Epoch [148/200], Training Loss: 0.0170, Training Accuracy: 99.86%, Test Loss: 0.6236, Test Accuracy: 85.30%
# Epoch [149/200], Training Loss: 0.0317, Training Accuracy: 98.31%, Test Loss: 0.7682, Test Accuracy: 82.32%
# Epoch [150/200], Training Loss: 0.0525, Training Accuracy: 99.61%, Test Loss: 0.6657, Test Accuracy: 84.43%
# Epoch [151/200], Training Loss: 0.0443, Training Accuracy: 98.91%, Test Loss: 0.7658, Test Accuracy: 82.16%
# Epoch [152/200], Training Loss: 0.0696, Training Accuracy: 95.23%, Test Loss: 0.9803, Test Accuracy: 78.71%
# Epoch [153/200], Training Loss: 0.0846, Training Accuracy: 99.22%, Test Loss: 0.6794, Test Accuracy: 83.57%
# Epoch [154/200], Training Loss: 0.0617, Training Accuracy: 97.28%, Test Loss: 0.7690, Test Accuracy: 81.56%
# Epoch [155/200], Training Loss: 0.1124, Training Accuracy: 98.41%, Test Loss: 0.6969, Test Accuracy: 83.10%
# Epoch [156/200], Training Loss: 0.0562, Training Accuracy: 99.44%, Test Loss: 0.6212, Test Accuracy: 84.82%
# Epoch [157/200], Training Loss: 0.0355, Training Accuracy: 99.22%, Test Loss: 0.7749, Test Accuracy: 82.49%
# Epoch [158/200], Training Loss: 0.0273, Training Accuracy: 99.93%, Test Loss: 0.5993, Test Accuracy: 85.71%
# Epoch [159/200], Training Loss: 0.0093, Training Accuracy: 99.96%, Test Loss: 0.5667, Test Accuracy: 86.77%
# Epoch [160/200], Training Loss: 0.0047, Training Accuracy: 99.96%, Test Loss: 0.5559, Test Accuracy: 87.04%
# Epoch [161/200], Training Loss: 0.0070, Training Accuracy: 100.00%, Test Loss: 0.5542, Test Accuracy: 87.39%
# Epoch [162/200], Training Loss: 0.0225, Training Accuracy: 99.61%, Test Loss: 0.7006, Test Accuracy: 84.00%
# Epoch [163/200], Training Loss: 0.0358, Training Accuracy: 99.61%, Test Loss: 0.6381, Test Accuracy: 85.14%
# Epoch [164/200], Training Loss: 0.0245, Training Accuracy: 99.82%, Test Loss: 0.6530, Test Accuracy: 84.86%
# Epoch [165/200], Training Loss: 0.0154, Training Accuracy: 99.61%, Test Loss: 0.6423, Test Accuracy: 84.59%
# Epoch [166/200], Training Loss: 0.0249, Training Accuracy: 99.96%, Test Loss: 0.6016, Test Accuracy: 85.77%
# Epoch [167/200], Training Loss: 0.0277, Training Accuracy: 99.33%, Test Loss: 0.7190, Test Accuracy: 83.95%
# Epoch [168/200], Training Loss: 0.0354, Training Accuracy: 99.36%, Test Loss: 0.7239, Test Accuracy: 83.28%
# Epoch [169/200], Training Loss: 0.0357, Training Accuracy: 98.23%, Test Loss: 0.8547, Test Accuracy: 81.99%
# Epoch [170/200], Training Loss: 0.0602, Training Accuracy: 97.78%, Test Loss: 0.9522, Test Accuracy: 79.77%
# Epoch [171/200], Training Loss: 0.0794, Training Accuracy: 98.69%, Test Loss: 0.7511, Test Accuracy: 82.82%
# Epoch [172/200], Training Loss: 0.1394, Training Accuracy: 97.49%, Test Loss: 0.7721, Test Accuracy: 81.53%
# Epoch [173/200], Training Loss: 0.2444, Training Accuracy: 96.26%, Test Loss: 0.7799, Test Accuracy: 79.85%
# Epoch [174/200], Training Loss: 0.1289, Training Accuracy: 98.38%, Test Loss: 0.7997, Test Accuracy: 80.80%
# Epoch [175/200], Training Loss: 0.0560, Training Accuracy: 99.33%, Test Loss: 0.6425, Test Accuracy: 84.18%
# Epoch [176/200], Training Loss: 0.0509, Training Accuracy: 99.75%, Test Loss: 0.6411, Test Accuracy: 84.64%
# Epoch [177/200], Training Loss: 0.0463, Training Accuracy: 99.86%, Test Loss: 0.5814, Test Accuracy: 85.89%
# Epoch [178/200], Training Loss: 0.0181, Training Accuracy: 99.86%, Test Loss: 0.5725, Test Accuracy: 85.75%
# Epoch [179/200], Training Loss: 0.0122, Training Accuracy: 99.96%, Test Loss: 0.5419, Test Accuracy: 87.25%
# Epoch [180/200], Training Loss: 0.0106, Training Accuracy: 99.96%, Test Loss: 0.5817, Test Accuracy: 86.37%
# Epoch [181/200], Training Loss: 0.0167, Training Accuracy: 99.82%, Test Loss: 0.5617, Test Accuracy: 86.41%
# Epoch [182/200], Training Loss: 0.0048, Training Accuracy: 100.00%, Test Loss: 0.5466, Test Accuracy: 86.97%
# Epoch [183/200], Training Loss: 0.0060, Training Accuracy: 100.00%, Test Loss: 0.5299, Test Accuracy: 87.81%
#
#
# Test accuracy increased (87.5297 --> 87.8085). Saving model ...
# Epoch [184/200], Training Loss: 0.0032, Training Accuracy: 100.00%, Test Loss: 0.5426, Test Accuracy: 87.65%
# Epoch [185/200], Training Loss: 0.0034, Training Accuracy: 100.00%, Test Loss: 0.5524, Test Accuracy: 87.06%
# Epoch [186/200], Training Loss: 0.0020, Training Accuracy: 100.00%, Test Loss: 0.5429, Test Accuracy: 87.80%
# Epoch [187/200], Training Loss: 0.0009, Training Accuracy: 100.00%, Test Loss: 0.5340, Test Accuracy: 88.25%
#
#
# Test accuracy increased (87.8085 --> 88.2512). Saving model ...
# Epoch [188/200], Training Loss: 0.0013, Training Accuracy: 100.00%, Test Loss: 0.5463, Test Accuracy: 87.78%
# Epoch [189/200], Training Loss: 0.0032, Training Accuracy: 100.00%, Test Loss: 0.5669, Test Accuracy: 87.26%
# Epoch [190/200], Training Loss: 0.0013, Training Accuracy: 100.00%, Test Loss: 0.5591, Test Accuracy: 87.70%
# Epoch [191/200], Training Loss: 0.0009, Training Accuracy: 100.00%, Test Loss: 0.5357, Test Accuracy: 88.20%
# Epoch [192/200], Training Loss: 0.0007, Training Accuracy: 100.00%, Test Loss: 0.5379, Test Accuracy: 88.33%
#
#
# Test accuracy increased (88.2512 --> 88.3332). Saving model ...
# Epoch [193/200], Training Loss: 0.0009, Training Accuracy: 100.00%, Test Loss: 0.5578, Test Accuracy: 87.48%
# Epoch [194/200], Training Loss: 0.0016, Training Accuracy: 100.00%, Test Loss: 0.5928, Test Accuracy: 86.65%
# Epoch [195/200], Training Loss: 0.0016, Training Accuracy: 100.00%, Test Loss: 0.5650, Test Accuracy: 87.84%
# Epoch [196/200], Training Loss: 0.0006, Training Accuracy: 100.00%, Test Loss: 0.5341, Test Accuracy: 88.32%
# Epoch [197/200], Training Loss: 0.0004, Training Accuracy: 100.00%, Test Loss: 0.5353, Test Accuracy: 88.40%
#
#
# Test accuracy increased (88.3332 --> 88.3988). Saving model ...
# Epoch [198/200], Training Loss: 0.0005, Training Accuracy: 100.00%, Test Loss: 0.5366, Test Accuracy: 88.41%
#
#
# Test accuracy increased (88.3988 --> 88.4070). Saving model ...
# Epoch [199/200], Training Loss: 0.0005, Training Accuracy: 100.00%, Test Loss: 0.5416, Test Accuracy: 88.42%
#
#
# Test accuracy increased (88.4070 --> 88.4234). Saving model ...
# Epoch [200/200], Training Loss: 0.0005, Training Accuracy: 100.00%, Test Loss: 0.5401, Test Accuracy: 88.33%
#
#
#
# The train time (in seconds) is: 390.9528968334198
# Test Loss: 0.5416
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 81, 144, 1]           6,642
#             Linear-2             [-1, 144, 128]          10,496
#          LayerNorm-3             [-1, 144, 128]             256
#            Dropout-4             [-1, 145, 128]               0
#     PatchEmbedding-5             [-1, 145, 128]               0
#             Conv2d-6             [-1, 81, 1, 1]           6,642
#             Linear-7               [-1, 1, 128]          10,496
#          LayerNorm-8               [-1, 1, 128]             256
#            Dropout-9               [-1, 2, 128]               0
#    PatchEmbedding-10               [-1, 2, 128]               0
#         LayerNorm-11             [-1, 145, 128]             256
#         LayerNorm-12             [-1, 145, 128]             256
#            Linear-13             [-1, 145, 512]          65,536
#            Linear-14             [-1, 145, 512]          65,536
#            Linear-15             [-1, 145, 512]          65,536
#           Dropout-16             [-1, 145, 512]               0
#            Linear-17             [-1, 145, 128]          65,664
#  HSISelfAttention-18             [-1, 145, 128]               0
#         LayerNorm-19             [-1, 145, 128]             256
#            Linear-20             [-1, 145, 256]          33,024
#              GELU-21             [-1, 145, 256]               0
#           Dropout-22             [-1, 145, 256]               0
#            Linear-23             [-1, 145, 128]          32,896
#           Dropout-24             [-1, 145, 128]               0
#               Mlp-25             [-1, 145, 128]               0
#             Block-26             [-1, 145, 128]               0
#         LayerNorm-27             [-1, 145, 128]             256
# TransformerEncoder-28             [-1, 145, 128]               0
#         LayerNorm-29               [-1, 2, 128]             256
#         LayerNorm-30               [-1, 2, 128]             256
#            Linear-31               [-1, 2, 512]          65,536
#            Linear-32               [-1, 2, 512]          65,536
#            Linear-33               [-1, 2, 512]          65,536
#           Dropout-34               [-1, 2, 512]               0
#            Linear-35               [-1, 2, 128]          65,664
#  HSISelfAttention-36               [-1, 2, 128]               0
#         LayerNorm-37               [-1, 2, 128]             256
#            Linear-38               [-1, 2, 256]          33,024
#              GELU-39               [-1, 2, 256]               0
#           Dropout-40               [-1, 2, 256]               0
#            Linear-41               [-1, 2, 128]          32,896
#           Dropout-42               [-1, 2, 128]               0
#               Mlp-43               [-1, 2, 128]               0
#             Block-44               [-1, 2, 128]               0
#         LayerNorm-45               [-1, 2, 128]             256
# TransformerEncoder-46               [-1, 2, 128]               0
#         LayerNorm-47             [-1, 145, 128]             256
#         LayerNorm-48             [-1, 145, 128]             256
#            Linear-49               [-1, 2, 512]          65,536
#            Linear-50             [-1, 145, 512]          65,536
#            Linear-51             [-1, 145, 512]          65,536
#           Dropout-52               [-1, 1, 512]               0
#            Linear-53               [-1, 1, 128]          65,664
# HSICrossAttention-54               [-1, 1, 128]               0
#         LayerNorm-55             [-1, 145, 128]             256
#            Linear-56             [-1, 145, 256]          33,024
#              GELU-57             [-1, 145, 256]               0
#           Dropout-58             [-1, 145, 256]               0
#            Linear-59             [-1, 145, 128]          32,896
#           Dropout-60             [-1, 145, 128]               0
#               Mlp-61             [-1, 145, 128]               0
#            BlockC-62             [-1, 145, 128]               0
#         LayerNorm-63             [-1, 145, 128]             256
#         LayerNorm-64             [-1, 145, 128]             256
#            Linear-65               [-1, 2, 512]          65,536
#            Linear-66             [-1, 145, 512]          65,536
#            Linear-67             [-1, 145, 512]          65,536
#           Dropout-68               [-1, 1, 512]               0
#            Linear-69               [-1, 1, 128]          65,664
# HSICrossAttention-70               [-1, 1, 128]               0
#         LayerNorm-71             [-1, 145, 128]             256
#            Linear-72             [-1, 145, 256]          33,024
#              GELU-73             [-1, 145, 256]               0
#           Dropout-74             [-1, 145, 256]               0
#            Linear-75             [-1, 145, 128]          32,896
#           Dropout-76             [-1, 145, 128]               0
#               Mlp-77             [-1, 145, 128]               0
#            BlockC-78             [-1, 145, 128]               0
#         LayerNorm-79             [-1, 145, 128]             256
# TransformerEncoderC-80             [-1, 145, 128]               0
#         LayerNorm-81               [-1, 2, 128]             256
#         LayerNorm-82               [-1, 2, 128]             256
#            Linear-83             [-1, 145, 512]          65,536
#            Linear-84               [-1, 2, 512]          65,536
#            Linear-85               [-1, 2, 512]          65,536
#           Dropout-86               [-1, 1, 512]               0
#            Linear-87               [-1, 1, 128]          65,664
# HSICrossAttention-88               [-1, 1, 128]               0
#         LayerNorm-89               [-1, 2, 128]             256
#            Linear-90               [-1, 2, 256]          33,024
#              GELU-91               [-1, 2, 256]               0
#           Dropout-92               [-1, 2, 256]               0
#            Linear-93               [-1, 2, 128]          32,896
#           Dropout-94               [-1, 2, 128]               0
#               Mlp-95               [-1, 2, 128]               0
#            BlockC-96               [-1, 2, 128]               0
#         LayerNorm-97               [-1, 2, 128]             256
#         LayerNorm-98               [-1, 2, 128]             256
#            Linear-99             [-1, 145, 512]          65,536
#           Linear-100               [-1, 2, 512]          65,536
#           Linear-101               [-1, 2, 512]          65,536
#          Dropout-102               [-1, 1, 512]               0
#           Linear-103               [-1, 1, 128]          65,664
# HSICrossAttention-104               [-1, 1, 128]               0
#        LayerNorm-105               [-1, 2, 128]             256
#           Linear-106               [-1, 2, 256]          33,024
#             GELU-107               [-1, 2, 256]               0
#          Dropout-108               [-1, 2, 256]               0
#           Linear-109               [-1, 2, 128]          32,896
#          Dropout-110               [-1, 2, 128]               0
#              Mlp-111               [-1, 2, 128]               0
#           BlockC-112               [-1, 2, 128]               0
#        LayerNorm-113               [-1, 2, 128]             256
# TransformerEncoderC-114               [-1, 2, 128]               0
#           Linear-115                   [-1, 15]           1,935
#           Linear-116                   [-1, 15]           1,935
# ================================================================
# Total params: 2,013,442
# Trainable params: 2,013,442
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.60
# Forward/backward pass size (MB): 12.89
# Params size (MB): 7.68
# Estimated Total Size (MB): 24.17
# ----------------------------------------------------------------
# Epoch [1/200], Training Loss: 2.7307, Training Accuracy: 12.11%, Test Loss: 2.6836, Test Accuracy: 12.03%
#
#
# Test accuracy increased (-inf --> 12.0275). Saving model ...
# Epoch [2/200], Training Loss: 2.4709, Training Accuracy: 22.85%, Test Loss: 2.4369, Test Accuracy: 17.07%
#
#
# Test accuracy increased (12.0275 --> 17.0698). Saving model ...
# Epoch [3/200], Training Loss: 2.1451, Training Accuracy: 42.27%, Test Loss: 2.0219, Test Accuracy: 33.60%
#
#
# Test accuracy increased (17.0698 --> 33.5984). Saving model ...
# Epoch [4/200], Training Loss: 1.7544, Training Accuracy: 48.06%, Test Loss: 1.7739, Test Accuracy: 39.49%
#
#
# Test accuracy increased (33.5984 --> 39.4933). Saving model ...
# Epoch [5/200], Training Loss: 1.5355, Training Accuracy: 53.53%, Test Loss: 1.6626, Test Accuracy: 44.22%
#
#
# Test accuracy increased (39.4933 --> 44.2158). Saving model ...
# Epoch [6/200], Training Loss: 1.3578, Training Accuracy: 58.09%, Test Loss: 1.6258, Test Accuracy: 44.02%
# Epoch [7/200], Training Loss: 1.2123, Training Accuracy: 65.50%, Test Loss: 1.3876, Test Accuracy: 53.51%
#
#
# Test accuracy increased (44.2158 --> 53.5132). Saving model ...
# Epoch [8/200], Training Loss: 1.0759, Training Accuracy: 68.50%, Test Loss: 1.2982, Test Accuracy: 55.58%
#
#
# Test accuracy increased (53.5132 --> 55.5792). Saving model ...
# Epoch [9/200], Training Loss: 0.9443, Training Accuracy: 70.69%, Test Loss: 1.2255, Test Accuracy: 58.33%
#
#
# Test accuracy increased (55.5792 --> 58.3340). Saving model ...
# Epoch [10/200], Training Loss: 0.8053, Training Accuracy: 71.79%, Test Loss: 1.3417, Test Accuracy: 56.67%
# Epoch [11/200], Training Loss: 0.7722, Training Accuracy: 79.06%, Test Loss: 1.0810, Test Accuracy: 64.23%
#
#
# Test accuracy increased (58.3340 --> 64.2289). Saving model ...
# Epoch [12/200], Training Loss: 0.6951, Training Accuracy: 81.07%, Test Loss: 0.9957, Test Accuracy: 66.68%
#
#
# Test accuracy increased (64.2289 --> 66.6803). Saving model ...
# Epoch [13/200], Training Loss: 0.6693, Training Accuracy: 79.17%, Test Loss: 1.0649, Test Accuracy: 63.85%
# Epoch [14/200], Training Loss: 0.5931, Training Accuracy: 82.13%, Test Loss: 0.9393, Test Accuracy: 67.48%
#
#
# Test accuracy increased (66.6803 --> 67.4838). Saving model ...
# Epoch [15/200], Training Loss: 0.5375, Training Accuracy: 82.66%, Test Loss: 1.0001, Test Accuracy: 66.39%
# Epoch [16/200], Training Loss: 0.5000, Training Accuracy: 86.26%, Test Loss: 0.9117, Test Accuracy: 69.16%
#
#
# Test accuracy increased (67.4838 --> 69.1563). Saving model ...
# Epoch [17/200], Training Loss: 0.4861, Training Accuracy: 87.25%, Test Loss: 0.9576, Test Accuracy: 68.67%
# Epoch [18/200], Training Loss: 0.4380, Training Accuracy: 90.25%, Test Loss: 0.7879, Test Accuracy: 74.58%
#
#
# Test accuracy increased (69.1563 --> 74.5757). Saving model ...
# Epoch [19/200], Training Loss: 0.4112, Training Accuracy: 90.64%, Test Loss: 0.8047, Test Accuracy: 73.04%
# Epoch [20/200], Training Loss: 0.3735, Training Accuracy: 88.74%, Test Loss: 0.8534, Test Accuracy: 72.65%
# Epoch [21/200], Training Loss: 0.2975, Training Accuracy: 91.74%, Test Loss: 0.7784, Test Accuracy: 74.24%
# Epoch [22/200], Training Loss: 0.3360, Training Accuracy: 92.41%, Test Loss: 0.7277, Test Accuracy: 76.60%
#
#
# Test accuracy increased (74.5757 --> 76.6008). Saving model ...
# Epoch [23/200], Training Loss: 0.2964, Training Accuracy: 92.69%, Test Loss: 0.7823, Test Accuracy: 74.26%
# Epoch [24/200], Training Loss: 0.2629, Training Accuracy: 89.97%, Test Loss: 0.9397, Test Accuracy: 72.50%
# Epoch [25/200], Training Loss: 0.2839, Training Accuracy: 94.24%, Test Loss: 0.7131, Test Accuracy: 77.43%
#
#
# Test accuracy increased (76.6008 --> 77.4289). Saving model ...
# Epoch [26/200], Training Loss: 0.2113, Training Accuracy: 91.60%, Test Loss: 0.8124, Test Accuracy: 74.69%
# Epoch [27/200], Training Loss: 0.2632, Training Accuracy: 91.91%, Test Loss: 0.7113, Test Accuracy: 76.38%
# Epoch [28/200], Training Loss: 0.2397, Training Accuracy: 92.55%, Test Loss: 0.8401, Test Accuracy: 74.13%
# Epoch [29/200], Training Loss: 0.1840, Training Accuracy: 96.50%, Test Loss: 0.6276, Test Accuracy: 80.06%
#
#
# Test accuracy increased (77.4289 --> 80.0607). Saving model ...
# Epoch [30/200], Training Loss: 0.1363, Training Accuracy: 94.92%, Test Loss: 0.7085, Test Accuracy: 78.68%
# Epoch [31/200], Training Loss: 0.1721, Training Accuracy: 96.79%, Test Loss: 0.6782, Test Accuracy: 79.37%
# Epoch [32/200], Training Loss: 0.1602, Training Accuracy: 97.14%, Test Loss: 0.6993, Test Accuracy: 79.59%
# Epoch [33/200], Training Loss: 0.1285, Training Accuracy: 96.36%, Test Loss: 0.7650, Test Accuracy: 78.59%
# Epoch [34/200], Training Loss: 0.2047, Training Accuracy: 94.70%, Test Loss: 0.8244, Test Accuracy: 75.97%
# Epoch [35/200], Training Loss: 0.2431, Training Accuracy: 94.81%, Test Loss: 0.7920, Test Accuracy: 76.67%
# Epoch [36/200], Training Loss: 0.1502, Training Accuracy: 96.75%, Test Loss: 0.7312, Test Accuracy: 78.04%
# Epoch [37/200], Training Loss: 0.1028, Training Accuracy: 96.72%, Test Loss: 0.7165, Test Accuracy: 79.11%
# Epoch [38/200], Training Loss: 0.1072, Training Accuracy: 97.63%, Test Loss: 0.6536, Test Accuracy: 80.20%
#
#
# Test accuracy increased (80.0607 --> 80.2000). Saving model ...
# Epoch [39/200], Training Loss: 0.1158, Training Accuracy: 97.85%, Test Loss: 0.6653, Test Accuracy: 80.27%
#
#
# Test accuracy increased (80.2000 --> 80.2738). Saving model ...
# Epoch [40/200], Training Loss: 0.1123, Training Accuracy: 96.54%, Test Loss: 0.7403, Test Accuracy: 79.57%
# Epoch [41/200], Training Loss: 0.1075, Training Accuracy: 98.31%, Test Loss: 0.6492, Test Accuracy: 81.21%
#
#
# Test accuracy increased (80.2738 --> 81.2085). Saving model ...
# Epoch [42/200], Training Loss: 0.0851, Training Accuracy: 98.38%, Test Loss: 0.6125, Test Accuracy: 82.21%
#
#
# Test accuracy increased (81.2085 --> 82.2087). Saving model ...
# Epoch [43/200], Training Loss: 0.1224, Training Accuracy: 95.30%, Test Loss: 0.7754, Test Accuracy: 78.32%
# Epoch [44/200], Training Loss: 0.1173, Training Accuracy: 98.48%, Test Loss: 0.6562, Test Accuracy: 81.06%
# Epoch [45/200], Training Loss: 0.1022, Training Accuracy: 97.95%, Test Loss: 0.6987, Test Accuracy: 80.00%
# Epoch [46/200], Training Loss: 0.1059, Training Accuracy: 98.02%, Test Loss: 0.6699, Test Accuracy: 81.08%
# Epoch [47/200], Training Loss: 0.1387, Training Accuracy: 98.23%, Test Loss: 0.6962, Test Accuracy: 80.23%
# Epoch [48/200], Training Loss: 0.0994, Training Accuracy: 96.54%, Test Loss: 0.7429, Test Accuracy: 79.61%
# Epoch [49/200], Training Loss: 0.0788, Training Accuracy: 98.23%, Test Loss: 0.6317, Test Accuracy: 82.32%
#
#
# Test accuracy increased (82.2087 --> 82.3153). Saving model ...
# Epoch [50/200], Training Loss: 0.0647, Training Accuracy: 99.01%, Test Loss: 0.6864, Test Accuracy: 81.48%
# Epoch [51/200], Training Loss: 0.0524, Training Accuracy: 99.05%, Test Loss: 0.6705, Test Accuracy: 82.04%
# Epoch [52/200], Training Loss: 0.0565, Training Accuracy: 99.01%, Test Loss: 0.7086, Test Accuracy: 81.59%
# Epoch [53/200], Training Loss: 0.0976, Training Accuracy: 94.63%, Test Loss: 0.9053, Test Accuracy: 77.90%
# Epoch [54/200], Training Loss: 0.1722, Training Accuracy: 98.27%, Test Loss: 0.7583, Test Accuracy: 79.49%
# Epoch [55/200], Training Loss: 0.1482, Training Accuracy: 97.53%, Test Loss: 0.7405, Test Accuracy: 80.05%
# Epoch [56/200], Training Loss: 0.1207, Training Accuracy: 97.42%, Test Loss: 0.7667, Test Accuracy: 79.32%
# Epoch [57/200], Training Loss: 0.0945, Training Accuracy: 98.73%, Test Loss: 0.6924, Test Accuracy: 81.02%
# Epoch [58/200], Training Loss: 0.0587, Training Accuracy: 99.72%, Test Loss: 0.5821, Test Accuracy: 84.52%
#
#
# ...
# Epoch [61/200], Training Loss: 0.0751, Training Accuracy: 99.01%, Test Loss: 0.7617, Test Accuracy: 80.31%
# Epoch [62/200], Training Loss: 0.0560, Training Accuracy: 99.58%, Test Loss: 0.7174, Test Accuracy: 82.06%
# Epoch [63/200], Training Loss: 0.0358, Training Accuracy: 99.51%, Test Loss: 0.6819, Test Accuracy: 82.50%
#
#
# Test accuracy increased (82.4055 --> 82.5039). Saving model ...
# Epoch [64/200], Training Loss: 0.0281, Training Accuracy: 99.61%, Test Loss: 0.7076, Test Accuracy: 82.49%
# Epoch [65/200], Training Loss: 0.0260, Training Accuracy: 99.15%, Test Loss: 0.7626, Test Accuracy: 81.61%
# Epoch [66/200], Training Loss: 0.0442, Training Accuracy: 95.27%, Test Loss: 0.9985, Test Accuracy: 77.50%
# Epoch [67/200], Training Loss: 0.1032, Training Accuracy: 98.13%, Test Loss: 0.8052, Test Accuracy: 80.59%
# Epoch [68/200], Training Loss: 0.0587, Training Accuracy: 99.19%, Test Loss: 0.8120, Test Accuracy: 80.27%
# Epoch [69/200], Training Loss: 0.0395, Training Accuracy: 99.58%, Test Loss: 0.7275, Test Accuracy: 81.95%
# Epoch [70/200], Training Loss: 0.0291, Training Accuracy: 98.69%, Test Loss: 0.8967, Test Accuracy: 79.91%
# Epoch [71/200], Training Loss: 0.0513, Training Accuracy: 96.93%, Test Loss: 0.9647, Test Accuracy: 77.72%
# Epoch [72/200], Training Loss: 0.0604, Training Accuracy: 98.98%, Test Loss: 0.7951, Test Accuracy: 80.94%
# Epoch [73/200], Training Loss: 0.0466, Training Accuracy: 98.55%, Test Loss: 0.7531, Test Accuracy: 81.91%
# Epoch [74/200], Training Loss: 0.0958, Training Accuracy: 97.99%, Test Loss: 0.8595, Test Accuracy: 79.76%
# Epoch [75/200], Training Loss: 0.2597, Training Accuracy: 94.88%, Test Loss: 0.9509, Test Accuracy: 76.15%
# Epoch [76/200], Training Loss: 0.1674, Training Accuracy: 96.01%, Test Loss: 0.9480, Test Accuracy: 75.88%
# Epoch [77/200], Training Loss: 0.1001, Training Accuracy: 98.87%, Test Loss: 0.7162, Test Accuracy: 82.23%
# Epoch [78/200], Training Loss: 0.0376, Training Accuracy: 99.89%, Test Loss: 0.6161, Test Accuracy: 84.18%
#
#
# Test accuracy increased (82.5039 --> 84.1764). Saving model ...
# Epoch [79/200], Training Loss: 0.0261, Training Accuracy: 99.79%, Test Loss: 0.6459, Test Accuracy: 83.64%
# Epoch [80/200], Training Loss: 0.0318, Training Accuracy: 99.68%, Test Loss: 0.6892, Test Accuracy: 82.53%
# Epoch [81/200], Training Loss: 0.0363, Training Accuracy: 98.27%, Test Loss: 0.9034, Test Accuracy: 78.63%
# Epoch [82/200], Training Loss: 0.0556, Training Accuracy: 99.36%, Test Loss: 0.7709, Test Accuracy: 81.98%
# Epoch [83/200], Training Loss: 0.0887, Training Accuracy: 98.13%, Test Loss: 0.8709, Test Accuracy: 79.08%
# Epoch [84/200], Training Loss: 0.0769, Training Accuracy: 98.80%, Test Loss: 0.7331, Test Accuracy: 82.02%
# Epoch [85/200], Training Loss: 0.0478, Training Accuracy: 99.44%, Test Loss: 0.6520, Test Accuracy: 83.75%
# Epoch [86/200], Training Loss: 0.0656, Training Accuracy: 99.19%, Test Loss: 0.7314, Test Accuracy: 82.24%
# Epoch [87/200], Training Loss: 0.1417, Training Accuracy: 96.96%, Test Loss: 0.7718, Test Accuracy: 79.90%
# Epoch [88/200], Training Loss: 0.0751, Training Accuracy: 99.51%, Test Loss: 0.7034, Test Accuracy: 82.55%
# Epoch [89/200], Training Loss: 0.0674, Training Accuracy: 97.70%, Test Loss: 0.8070, Test Accuracy: 80.09%
# Epoch [90/200], Training Loss: 0.1204, Training Accuracy: 98.66%, Test Loss: 0.6664, Test Accuracy: 82.74%
# Epoch [91/200], Training Loss: 0.1231, Training Accuracy: 98.16%, Test Loss: 0.8285, Test Accuracy: 79.72%
# Epoch [92/200], Training Loss: 0.0628, Training Accuracy: 98.20%, Test Loss: 0.7792, Test Accuracy: 81.37%
# Epoch [93/200], Training Loss: 0.0663, Training Accuracy: 99.36%, Test Loss: 0.6850, Test Accuracy: 82.62%
# Epoch [94/200], Training Loss: 0.0346, Training Accuracy: 99.68%, Test Loss: 0.6744, Test Accuracy: 83.67%
# Epoch [95/200], Training Loss: 0.0167, Training Accuracy: 99.93%, Test Loss: 0.6330, Test Accuracy: 84.27%
#
#
# Test accuracy increased (84.1764 --> 84.2666). Saving model ...
# Epoch [96/200], Training Loss: 0.0125, Training Accuracy: 99.82%, Test Loss: 0.6600, Test Accuracy: 84.77%
#
#
# Test accuracy increased (84.2666 --> 84.7667). Saving model ...
# Epoch [97/200], Training Loss: 0.0209, Training Accuracy: 99.26%, Test Loss: 0.7213, Test Accuracy: 82.92%
# Epoch [98/200], Training Loss: 0.0359, Training Accuracy: 99.58%, Test Loss: 0.7708, Test Accuracy: 82.37%
# Epoch [99/200], Training Loss: 0.0261, Training Accuracy: 99.51%, Test Loss: 0.7269, Test Accuracy: 83.68%
# Epoch [100/200], Training Loss: 0.0371, Training Accuracy: 98.98%, Test Loss: 0.7914, Test Accuracy: 82.05%
# Epoch [101/200], Training Loss: 0.0255, Training Accuracy: 99.75%, Test Loss: 0.7372, Test Accuracy: 83.22%
# Epoch [102/200], Training Loss: 0.0927, Training Accuracy: 98.55%, Test Loss: 0.8150, Test Accuracy: 80.54%
# Epoch [103/200], Training Loss: 0.0860, Training Accuracy: 98.38%, Test Loss: 0.8992, Test Accuracy: 79.49%
# Epoch [104/200], Training Loss: 0.1085, Training Accuracy: 98.66%, Test Loss: 0.8530, Test Accuracy: 80.51%
# Epoch [105/200], Training Loss: 0.0736, Training Accuracy: 97.67%, Test Loss: 0.9327, Test Accuracy: 78.86%
# Epoch [106/200], Training Loss: 0.0670, Training Accuracy: 98.55%, Test Loss: 0.8404, Test Accuracy: 79.77%
# Epoch [107/200], Training Loss: 0.0768, Training Accuracy: 98.87%, Test Loss: 0.7740, Test Accuracy: 81.68%
# Epoch [108/200], Training Loss: 0.0771, Training Accuracy: 98.91%, Test Loss: 0.7723, Test Accuracy: 82.40%
# Epoch [109/200], Training Loss: 0.0809, Training Accuracy: 97.85%, Test Loss: 0.8152, Test Accuracy: 79.98%
# Epoch [110/200], Training Loss: 0.0673, Training Accuracy: 99.29%, Test Loss: 0.7445, Test Accuracy: 82.65%
# Epoch [111/200], Training Loss: 0.0505, Training Accuracy: 99.54%, Test Loss: 0.7434, Test Accuracy: 81.88%
# Epoch [112/200], Training Loss: 0.0496, Training Accuracy: 99.75%, Test Loss: 0.6269, Test Accuracy: 84.45%
# Epoch [113/200], Training Loss: 0.0431, Training Accuracy: 99.75%, Test Loss: 0.6950, Test Accuracy: 82.98%
# Epoch [114/200], Training Loss: 0.0413, Training Accuracy: 99.89%, Test Loss: 0.6924, Test Accuracy: 83.97%
# Epoch [115/200], Training Loss: 0.0405, Training Accuracy: 99.36%, Test Loss: 0.8313, Test Accuracy: 81.09%
# Epoch [116/200], Training Loss: 0.0501, Training Accuracy: 98.94%, Test Loss: 0.8069, Test Accuracy: 81.03%
# Epoch [117/200], Training Loss: 0.0714, Training Accuracy: 99.29%, Test Loss: 0.7288, Test Accuracy: 82.15%
# Epoch [118/200], Training Loss: 0.0444, Training Accuracy: 99.68%, Test Loss: 0.7058, Test Accuracy: 83.23%
# Epoch [119/200], Training Loss: 0.0298, Training Accuracy: 99.79%, Test Loss: 0.7328, Test Accuracy: 83.62%
# Epoch [120/200], Training Loss: 0.0314, Training Accuracy: 99.96%, Test Loss: 0.6809, Test Accuracy: 83.80%
# Epoch [121/200], Training Loss: 0.0114, Training Accuracy: 99.93%, Test Loss: 0.6880, Test Accuracy: 84.44%
# Epoch [122/200], Training Loss: 0.0130, Training Accuracy: 100.00%, Test Loss: 0.6388, Test Accuracy: 85.56%
#
#
# Test accuracy increased (84.7667 --> 85.5620). Saving model ...
# Epoch [123/200], Training Loss: 0.0056, Training Accuracy: 99.96%, Test Loss: 0.6285, Test Accuracy: 86.10%
#
#
# Test accuracy increased (85.5620 --> 86.1031). Saving model ...
# Epoch [124/200], Training Loss: 0.0111, Training Accuracy: 99.96%, Test Loss: 0.6757, Test Accuracy: 84.97%
# Epoch [125/200], Training Loss: 0.0182, Training Accuracy: 99.93%, Test Loss: 0.7402, Test Accuracy: 82.86%
# Epoch [126/200], Training Loss: 0.0340, Training Accuracy: 99.96%, Test Loss: 0.7039, Test Accuracy: 83.93%
# Epoch [127/200], Training Loss: 0.0068, Training Accuracy: 100.00%, Test Loss: 0.6299, Test Accuracy: 85.89%
# Epoch [128/200], Training Loss: 0.0049, Training Accuracy: 100.00%, Test Loss: 0.6569, Test Accuracy: 85.84%
# Epoch [129/200], Training Loss: 0.0040, Training Accuracy: 100.00%, Test Loss: 0.6361, Test Accuracy: 86.29%
#
#
# Test accuracy increased (86.1031 --> 86.2917). Saving model ...
# Epoch [130/200], Training Loss: 0.0056, Training Accuracy: 99.96%, Test Loss: 0.6999, Test Accuracy: 84.70%
# Epoch [131/200], Training Loss: 0.0130, Training Accuracy: 100.00%, Test Loss: 0.6892, Test Accuracy: 85.06%
# Epoch [132/200], Training Loss: 0.0261, Training Accuracy: 99.61%, Test Loss: 0.7325, Test Accuracy: 83.56%
# Epoch [133/200], Training Loss: 0.0292, Training Accuracy: 99.61%, Test Loss: 0.7669, Test Accuracy: 83.82%
# Epoch [134/200], Training Loss: 0.0514, Training Accuracy: 95.73%, Test Loss: 1.1427, Test Accuracy: 77.27%
# Epoch [135/200], Training Loss: 0.2653, Training Accuracy: 89.16%, Test Loss: 1.0857, Test Accuracy: 74.47%
# Epoch [136/200], Training Loss: 0.2965, Training Accuracy: 95.76%, Test Loss: 0.8577, Test Accuracy: 78.72%
# Epoch [137/200], Training Loss: 0.1067, Training Accuracy: 98.87%, Test Loss: 0.7211, Test Accuracy: 81.09%
# Epoch [138/200], Training Loss: 0.0458, Training Accuracy: 99.68%, Test Loss: 0.6856, Test Accuracy: 83.35%
# Epoch [139/200], Training Loss: 0.0231, Training Accuracy: 99.79%, Test Loss: 0.6346, Test Accuracy: 84.67%
# Epoch [140/200], Training Loss: 0.0333, Training Accuracy: 99.72%, Test Loss: 0.7101, Test Accuracy: 83.14%
# Epoch [141/200], Training Loss: 0.0195, Training Accuracy: 99.96%, Test Loss: 0.5856, Test Accuracy: 85.56%
# Epoch [142/200], Training Loss: 0.0150, Training Accuracy: 99.86%, Test Loss: 0.6422, Test Accuracy: 84.14%
# Epoch [143/200], Training Loss: 0.0142, Training Accuracy: 100.00%, Test Loss: 0.5984, Test Accuracy: 85.72%
# Epoch [144/200], Training Loss: 0.0036, Training Accuracy: 100.00%, Test Loss: 0.5805, Test Accuracy: 86.15%
# Epoch [145/200], Training Loss: 0.0039, Training Accuracy: 100.00%, Test Loss: 0.5905, Test Accuracy: 86.40%
#
#
# Test accuracy increased (86.2917 --> 86.3983). Saving model ...
# Epoch [146/200], Training Loss: 0.0019, Training Accuracy: 100.00%, Test Loss: 0.5754, Test Accuracy: 86.82%
#
#
# Test accuracy increased (86.3983 --> 86.8246). Saving model ...
# Epoch [147/200], Training Loss: 0.0014, Training Accuracy: 100.00%, Test Loss: 0.5825, Test Accuracy: 86.71%
# Epoch [148/200], Training Loss: 0.0016, Training Accuracy: 100.00%, Test Loss: 0.5817, Test Accuracy: 86.54%
# Epoch [149/200], Training Loss: 0.0043, Training Accuracy: 100.00%, Test Loss: 0.6228, Test Accuracy: 86.36%
# Epoch [150/200], Training Loss: 0.0020, Training Accuracy: 100.00%, Test Loss: 0.5988, Test Accuracy: 86.73%
# Epoch [151/200], Training Loss: 0.0014, Training Accuracy: 100.00%, Test Loss: 0.5809, Test Accuracy: 87.10%
#
#
# Test accuracy increased (86.8246 --> 87.0952). Saving model ...
# Epoch [152/200], Training Loss: 0.0007, Training Accuracy: 100.00%, Test Loss: 0.5786, Test Accuracy: 87.03%
# Epoch [153/200], Training Loss: 0.0044, Training Accuracy: 99.82%, Test Loss: 0.5960, Test Accuracy: 86.78%
# Epoch [154/200], Training Loss: 0.0113, Training Accuracy: 99.40%, Test Loss: 0.7985, Test Accuracy: 82.71%
# Epoch [155/200], Training Loss: 0.0251, Training Accuracy: 99.47%, Test Loss: 0.7897, Test Accuracy: 82.45%
# Epoch [156/200], Training Loss: 0.0645, Training Accuracy: 98.31%, Test Loss: 0.8408, Test Accuracy: 80.56%
# Epoch [157/200], Training Loss: 0.1026, Training Accuracy: 98.80%, Test Loss: 0.7552, Test Accuracy: 82.14%
# Epoch [158/200], Training Loss: 0.0892, Training Accuracy: 98.34%, Test Loss: 0.8302, Test Accuracy: 80.76%
# Epoch [159/200], Training Loss: 0.1020, Training Accuracy: 96.96%, Test Loss: 0.7832, Test Accuracy: 80.94%
# Epoch [160/200], Training Loss: 0.1064, Training Accuracy: 98.02%, Test Loss: 0.7963, Test Accuracy: 81.39%
# Epoch [161/200], Training Loss: 0.1281, Training Accuracy: 98.27%, Test Loss: 0.8005, Test Accuracy: 80.85%
# Epoch [162/200], Training Loss: 0.0659, Training Accuracy: 99.05%, Test Loss: 0.7323, Test Accuracy: 81.99%
# Epoch [163/200], Training Loss: 0.0526, Training Accuracy: 99.51%, Test Loss: 0.7261, Test Accuracy: 82.29%
# Epoch [164/200], Training Loss: 0.0292, Training Accuracy: 99.65%, Test Loss: 0.7587, Test Accuracy: 82.64%
# Epoch [165/200], Training Loss: 0.0111, Training Accuracy: 99.93%, Test Loss: 0.6434, Test Accuracy: 84.97%
# Epoch [166/200], Training Loss: 0.0183, Training Accuracy: 99.96%, Test Loss: 0.6335, Test Accuracy: 84.85%
# Epoch [167/200], Training Loss: 0.0123, Training Accuracy: 100.00%, Test Loss: 0.6353, Test Accuracy: 85.64%
# Epoch [168/200], Training Loss: 0.0046, Training Accuracy: 100.00%, Test Loss: 0.6114, Test Accuracy: 86.11%
# Epoch [169/200], Training Loss: 0.0107, Training Accuracy: 99.96%, Test Loss: 0.6579, Test Accuracy: 85.29%
# Epoch [170/200], Training Loss: 0.0591, Training Accuracy: 99.68%, Test Loss: 0.7112, Test Accuracy: 84.55%
# Epoch [171/200], Training Loss: 0.0403, Training Accuracy: 99.44%, Test Loss: 0.7617, Test Accuracy: 83.15%
# Epoch [172/200], Training Loss: 0.0634, Training Accuracy: 98.73%, Test Loss: 0.7791, Test Accuracy: 81.62%
# Epoch [173/200], Training Loss: 0.1111, Training Accuracy: 97.74%, Test Loss: 0.7934, Test Accuracy: 81.03%
# Epoch [174/200], Training Loss: 0.0512, Training Accuracy: 98.76%, Test Loss: 0.8143, Test Accuracy: 82.28%
# Epoch [175/200], Training Loss: 0.0297, Training Accuracy: 99.61%, Test Loss: 0.6803, Test Accuracy: 84.81%
# Epoch [176/200], Training Loss: 0.0508, Training Accuracy: 99.54%, Test Loss: 0.7164, Test Accuracy: 83.46%
# Epoch [177/200], Training Loss: 0.0491, Training Accuracy: 99.47%, Test Loss: 0.7154, Test Accuracy: 83.52%
# Epoch [178/200], Training Loss: 0.0568, Training Accuracy: 99.86%, Test Loss: 0.6970, Test Accuracy: 83.86%
# Epoch [179/200], Training Loss: 0.0540, Training Accuracy: 98.16%, Test Loss: 0.8128, Test Accuracy: 80.81%
# Epoch [180/200], Training Loss: 0.0552, Training Accuracy: 99.44%, Test Loss: 0.7266, Test Accuracy: 84.15%
# Epoch [181/200], Training Loss: 0.0353, Training Accuracy: 99.15%, Test Loss: 0.7182, Test Accuracy: 83.50%
# Epoch [182/200], Training Loss: 0.0315, Training Accuracy: 99.61%, Test Loss: 0.7105, Test Accuracy: 84.04%
# Epoch [183/200], Training Loss: 0.0183, Training Accuracy: 99.79%, Test Loss: 0.6539, Test Accuracy: 85.04%
# Epoch [184/200], Training Loss: 0.0214, Training Accuracy: 99.82%, Test Loss: 0.6246, Test Accuracy: 86.04%
# Epoch [185/200], Training Loss: 0.0096, Training Accuracy: 99.75%, Test Loss: 0.6531, Test Accuracy: 85.70%
# Epoch [186/200], Training Loss: 0.0103, Training Accuracy: 100.00%, Test Loss: 0.6021, Test Accuracy: 86.09%
# Epoch [187/200], Training Loss: 0.0063, Training Accuracy: 99.96%, Test Loss: 0.5991, Test Accuracy: 86.56%
# Epoch [188/200], Training Loss: 0.0060, Training Accuracy: 100.00%, Test Loss: 0.5975, Test Accuracy: 86.72%
# Epoch [189/200], Training Loss: 0.0034, Training Accuracy: 100.00%, Test Loss: 0.5587, Test Accuracy: 87.46%
#
#
# Test accuracy increased (87.0952 --> 87.4641). Saving model ...
# Epoch [190/200], Training Loss: 0.0051, Training Accuracy: 99.93%, Test Loss: 0.6146, Test Accuracy: 86.54%
# Epoch [191/200], Training Loss: 0.0115, Training Accuracy: 99.54%, Test Loss: 0.7427, Test Accuracy: 84.31%
# Epoch [192/200], Training Loss: 0.0152, Training Accuracy: 99.89%, Test Loss: 0.6420, Test Accuracy: 86.02%
# Epoch [193/200], Training Loss: 0.0248, Training Accuracy: 98.87%, Test Loss: 0.8076, Test Accuracy: 81.66%
# Epoch [194/200], Training Loss: 0.0810, Training Accuracy: 97.39%, Test Loss: 0.9117, Test Accuracy: 80.45%
# Epoch [195/200], Training Loss: 0.1159, Training Accuracy: 98.73%, Test Loss: 0.8039, Test Accuracy: 80.65%
# Epoch [196/200], Training Loss: 0.0555, Training Accuracy: 98.66%, Test Loss: 0.8750, Test Accuracy: 80.66%
# Epoch [197/200], Training Loss: 0.0469, Training Accuracy: 98.94%, Test Loss: 0.7105, Test Accuracy: 83.33%
# Epoch [198/200], Training Loss: 0.0440, Training Accuracy: 99.51%, Test Loss: 0.7008, Test Accuracy: 83.93%
# Epoch [199/200], Training Loss: 0.0390, Training Accuracy: 99.89%, Test Loss: 0.7125, Test Accuracy: 84.57%
# Epoch [200/200], Training Loss: 0.0173, Training Accuracy: 99.65%, Test Loss: 0.7349, Test Accuracy: 84.10%
#
#
#
# The train time (in seconds) is: 391.07594990730286
# Test Loss: 0.5587
